# %%
from datasets import load_dataset
import os
import json
from collections import Counter
import numpy as np

from utils import join_tokens

import random

# %%
pretrain_dir = f"data_pretrain/"

# %%
def explore_dataset(data : list[dict]):
    print(f"length : {len(data)}")
    print(f"avg tokenized text length : {np.mean([len(sample['tokenized_text']) for sample in data])}")
    print(f"max tokenized text length : {max([len(sample['tokenized_text']) for sample in data])}")
    print(f"min tokenized text length : {min([len(sample['tokenized_text']) for sample in data])}")
    labels = set([ner[2] for sample in data for ner in sample['ner']])
    print(f"labels : {labels}")

# %%
def get_label_dict(data : list[dict],most_common = 0):
    output =  Counter([ner[2] for sample in data for ner in sample['ner']])

    if most_common:
        return output.most_common(most_common)
    
    else:
        return output

# %%
def print_sample_text(data,num_samples = 10,seed = 42,joined = True):
    random.seed(seed)

    samples = random.sample(data,num_samples)

    for sample in samples:
        if joined:
            print(join_tokens(sample['tokenized_text']),'\n')
        else:
            print(sample['tokenized_text'],'\n')

# %%
def print_entities(data,num_samples = 10, seed = 42,neighboring = 1,label = None):
    random.seed(seed)

    if label:
        data = [sample for sample in data if label in [ner[2] for ner in sample['ner']]]
        
    samples = random.sample(data,num_samples)

    for i,sample in enumerate(samples):
        print(f"sample {i +1}")
        ners = sample['ner']
        if label:
            ners = [ner for ner in ners if ner[2]==label]
        tok_text = sample['tokenized_text']

        if neighboring:
            tokens = [str(tok_text[ner[0]-int(neighboring):ner[1]+1 + int(neighboring)]) for ner in ners]
            print(", ".join([f"label={ner[2]}, neighboring tokens={token}" for ner, token in zip(ners, tokens)]))

        if not neighboring:
            tokens = [str(tok_text[ner[0]:ner[1]]) for ner in ners]
            print(", ".join([f"label={ner[2]}, neighboring tokens={token}" for ner, token in zip(ners, tokens)]))

# %%
def explore_label(data,label : 'str', most_common = 20):
    entities_per_label = []

    for sample in data:
        ranges_per_label = [[ner_tag[0],ner_tag[1]] for ner_tag in sample['ner'] if ner_tag[2] == label]
        entities_per_label.extend([join_tokens(sample['tokenized_text'][index[0]:index[1]+1]) for index in ranges_per_label])

    tot_ent = len(entities_per_label)
    unique_ent = np.unique(entities_per_label)

    print(f"total number of entities for label {label}: {tot_ent}")
    print(f"total number of unique entities for label {label} : {len(unique_ent)}")
    print(f"Ratio of unique/total entities : {len(unique_ent)/tot_ent}")
    return Counter(entities_per_label).most_common(most_common)

# %% [markdown]
# # urchade/pile_mistral_v0.1
# Used to train urchade/gliner_multi-v2.1

# %%
with open(os.path.join(pretrain_dir,"pile_mistral_v0.1.json"),'r') as f:
    pile_mistral = json.load(f)

# %%
explore_dataset(pile_mistral)
# Out:
# length : 19724
# avg tokenized text length : 210.39429121881972
# max tokenized text length : 711
# min tokenized text length : 1
# labels : {'', 'Pharmaceutical Development', 'Urban planner', 'Reign', 'Common Noun', 'Sexually_transmitted', 'Chronic Kidney Disease', 'Academic Journal', 'Massacre', 'California sea lion', 'Visiting', 'Cleaning Compound', 'Analyzer Name', 'Deadline', 'Particle size', 'Accredited Test Facility', 'Postpartum', 'Landmark', 'Shame', 'Standard Series', 'DFL colleague', 'Car Manufacturer', 'Water cleansing', 'Apoptotic events in breast cancer cells', 'Adjustable Element', 'Data Storage System', 'Approaches', 'Biodegradable Polymer', 'Part of Facemask', 'Yeast Cells', 'Filter Option', 'Birmingham, Ala.', 'Sub-district', 'Circuit', 'Corporate Vice President', 'Registered', 'HealthService', 'Valve', 'Pregnancy', 'Military Pilot', 'Temporary Job', 'Muscle Fibre', 'Interest Rate', 'Bluetooth Address', 'Network driver type', 'Former Medicare administrator', 'CardinalNumber', 'Film Title', 'Bicycle Advocacy Group', 'Supply Line', 'DDS, MS, PhD', 'Implement', 'Academic Title', 'Destination', 'Politician and Religious Leader', 'Amines', 'Elite Military Force', 'Workplace', 'Anomaly', 'Bracket', 'DisorderOrDisease', 'Security Token', 'Shopping Precinct', 'Display Illumination Method', 'Imaging_Technique', 'Flow Rate', 'Train service', 'Constraint', 'Risk', 'Publication Title', 'AutomationTool', 'Calendar', 'Graduation Year', 'Carriage', 'Quantum Hall Effect', 'ArmyGroup', 'Households', 'Particle', 'Product Type', 'State Counsellor', 'Textbook', 'Research Programme', 'Sugar', 'Media File', 'TV Ratings Firm', 'Patent Attorney', 'Health Official', 'Brand name', 'Full Text', 'LPN Program', 'Department of Defense', 'Symptomless', 'Toner', 'Name of a specific questionnaire used in the study', 'Film Production Company', 'Labor Leader', 'Nut Holder Leg', 'MHC class I-related molecule', 'City Group', 'Address term', 'Revolutionizing Optical Systems', 'Denomination/Movement', 'Healthcare Center', 'Supercomputer', 'Power', 'Bathroom', 'Special District', 'PN_admixture', 'Mathematical Field', 'Grasshopper', 'Traders', 'ElasticSearch Server Address', 'Catholic association', 'Marine Mammal', 'Cervical Abnormality', 'Financial Data', 'Business Tycoon', 'Sports Program', 'Atoll', 'Russian Language School', 'Calculation-target area', 'Body Systems', 'Gel phase', 'PublicServices', 'Five Days', 'SwimmingEvent', 'Climate Control', 'Healthcare Worker', 'Java Interface', 'Housing estates', 'Package Manager', 'Link Identifier', 'Property Condition', 'Color Adjustment', 'User profile', ' French Ex-Investor', 'Sports Administrator', 'Computation', 'Scammers', 'Neurophysiological process', 'Houses', 'Business Enterprise', 'Romantic pursuit', 'Megadonor', 'Red Supergiant', 'Australian social entrepreneur', 'National Route', 'Bystander', 'MeteorShower', 'Port', 'Beauty Subscription Service', 'District', 'Construction Company', 'Scientific', 'Changeable', 'Award ceremony', 'World of Warcraft Difficulty Level', 'Age range', 'Recycling', 'Patent Application Publication', 'CommercialEntity', 'Job Function', 'Fuzzy K-nearest Neighbor Algorithm', 'Array', 'Collection of individuals', 'Cryptocurrency Company', 'Podcast Host', 'Justifications', 'Musical Instruction', 'HolidayWeekend', 'Testing Cycle', 'Federal Bureau of Investigation', 'Immunological assay', 'Time Range', 'Microbe', 'Meat Reduction Campaign Manager', 'Scientific Society', 'Scientific Name', 'Microspheres', 'Sports Museum', 'African Artist', 'Global CCO', 'Health Care Services', 'Monetary amount', 'PKAInhibitor', 'Deputado', 'United States Code', 'Multimedia Feature', 'Problem', 'Consulting', 'Low Reinforcement', 'Candy_Company', 'Calibration Standards', 'Secure Shell', 'Positive Predictive Value', 'Research and Development', 'Health Foundation', 'City Councilwoman', 'President of Hillsdale College', 'Type of SAH', 'Case Report', 'Crisis', 'Gammarid', 'Renewable Energy Company', 'Handbag', 'Capacity Building / Professional Development', 'Labor Union Leader', 'Political Union', 'Artist, Scientist', 'Tracking Com ...

# %%
get_label_dict(pile_mistral,most_common = 15)
# Out:
# Counter({'Organization': 22122,
#          'Person': 21283,
#          'Location': 16524,
#          'Event': 5233,
#          'Quantity': 4725,
#          'Country': 4353,
#          'Time': 3120,
#          'Group': 3042,
#          'City': 2992,
#          'Product': 2726,
#          'Technology': 2623,
#          'Date': 2546,
#          'Politician': 2142,
#          'Software': 1967,
#          'Disease': 1758,
#          'Company': 1474,
#          'Substance': 1442,
#          'Number': 1431,
#          'Year': 1430,
#          'Concept': 1427,
#          'Variable': 1305,
#          'Compound': 1264,
#          'Protein': 1204,
#          'State': 1182,
#          'Process': 1166,
#          'Object': 1124,
#          'Action': 1123,
#          'Material': 1071,
#          'Condition': 1046,
#          'Device': 1021,
#          'Author': 875,
#          'Entity': 813,
#          'Artifact': 812,
#          'University': 687,
#          'Topic': 679,
#          'Determiner': 668,
#          'Animal': 653,
#          'Sports Team': 645,
#          'Procedure': 636,
#          'Football Club': 615,
#          'Media': 614,
#          'Actor': 600,
#          'Document': 561,
#          'ChemicalSubstance': 557,
#          'Percentage': 543,
#          'Measurement': 536,
#          'Component': 529,
#          'Drug': 525,
#          'Speaker': 514,
#          'Food': 513,
#          'Species': 506,
#          'Property': 501,
#          'Statement': 491,
#          'Government Agency': 461,
#          'Political Party': 453,
#          'Character': 451,
#          'Class': 450,
#          'Duration': 449,
#          'Website': 446,
#          'Chemical Substance': 442,
#          'Cell': 442,
#          'Organism': 430,
#          'Government': 430,
#          'Building': 424,
#          'Anatomical Structure': 423,
#          'Relation': 420,
#          'Court': 411,
#          'Type': 406,
#          'Month': 400,
#          'None': 397,
#          'Space': 389,
#          'Technique': 386,
#          'Legislation': 383,
#          'Text': 375,
#          'Thing': 372,
#          'Musician': 364,
#          'Educational Institution': 360,
#          'Verb': 358,
#          'Money': 353,
#          'Service': 346,
#          'Role': 342,
#          'Physical Object': 336,
#          'Function': 329,
#          'Name': 325,
#          'Demographic': 321,
#          'Measure': 320,
#          'Abstract': 314,
#          'Region': 312,
#          'Preposition': 308,
#          'Technology Company': 308,
#          'Abbreviation': 292,
#          'Plant': 288,
#          'Description': 287,
#          'Chemical substance': 278,
#          'Footballer': 272,
#          'People': 268,
#          'Judge': 262,
#          'Medical Condition': 259,
#          'Artwork': 252,
#          'Method': 252,
#          'County': 249,
#          'Book': 248,
#          'Publication': 246,
#          'Journalist': 242,
#          'Database': 242,
#          'Game': 241,
#          'Defendant': 238,
#          'Movie': 234,
#          'Quality': 233,
#          'Currency': 231,
#          'Military': 231,
#          'Category': 229,
#          'Integer': 227,
#          'Biological Entity': 225,
#          'Business': 223,
#          'Language': 223,
#          'Enzyme': 220,
#          'Operating System': 215,
#          'Study': 211,
#          'Lawyer': 210,
#          'Constant': 207,
#          'Vehicle': 206,
#          'Profession': 206,
#          'Village': 205,
#          'Attribute': 204,
#          'Gene': 204,
#          'Occupation': 202,
#          'N/A': 202,
#          'Athlete': 200,
#          'Artist': 197,
#          'Bacteria': 197,
#          'Activity': 196,
#          'Industry': 196,
#          'Adjective': 195,
#          'Medical Procedure': 195,
#          'Transportation': 194,
#          'Province': 192,
#          'Scientist': 188,
#          'Conjunction': 188,
#          'Organ': 188,
#          'Director': 187,
#          'Retailer': 187,
#          'PhysicalObject': 186,
#          'Appellant': 186,
#          'File': 186,
#          'Library': 185,
#          'Application': 179,
#          'Job Title': 178,
#          'Day': 176,
#          'Identifier': 171,
#          'TV Show': 169,
#          'Data': 168,
#          'Sports League': 168,
#          'Title': 166,
#          'Unknown': 164,
#          'Pronoun': 163,
#          'Period': 163,
#          'Metal': 162,
#          'Chemical': 162,
#          'Football Player': 161,
#          'Emotion': 161,
#          'Town': 159,
#          'Biological Process': 158,
#          'MedicalCondition': 158,
#          'Cryptocurrency': 157,
#          'Symptom': 157,
#          'Health Condition': 157,
#          'Telecommunications Company': 155,
#          'Manufacturer': 154,
#          'Video Game': 154,
#          'Nationality': 153,
#          'Media Company': 152,
#          'String': 150,
#          'Element': 150,
#          'Biological process': 149,
#          'System': 149,
#          'Noun': 148,
#          'Amount': 148,
#          'Newspaper': 148,
#          'Gender': 147,
#          'Female': 147,
#          'School': 147,
#          'Treatment': 145,
#          'Plaintiff': 145,
#          'ProgrammingLanguage': 144,
#          'Sports Event': 143,
#          'Baseball Player': 141,
#          'Singer': 141,
#          'Streaming Service': 140,
#          'Project': 138,
#          'Medication': 137,
#          'Programming Language': 137,
#          'Collection': 135,
#          'Program': 134,
#          'Award': 134,
#          'Media Outlet': 133,
#          'Brand': 131,
#          'Field': 130,
#          'Sport': 129,
#          'PERSON': 125,
#          'President': 124,
#          'Patent': 124,
#          'Basketball Player': 123,
#          'Subject': 123,
#          'Former President': 122,
#          'Liquid': 122,
#          'Team': 121,
#          'Automobile Manufacturer': 121,
#          'OperatingSystem': 120,
#          'Qualifier': 119,
#          'Student': 118,
#          'Political Entity': 117,
#          'Machine': 117,
#          'Model': 117,
#          'Bank': 117,
#          'Facility': 116,
#          'Department': 116,
#          'Question': 116,
#          'Age': 115,
#          'CEO': 115,
#          'Continent': 115,
#          'MedicalProcedure': 115,
#          'BodyPart': 114,
#          'Value': 113,
#          'Hospital': 113,
#          'Patient': 112,
#          'District': 111,
#          'Island': 111,
#          'Health': 110,
#          'Research': 110,
#          'BiologicalEntity': 108,
#          'Container': 108,
#          'Street': 107,
#          'Baseball Team': 107,
#          'News Agency': 107,
#          'Founder': 107,
#          'Car Manufacturer': 107,
#          'Statistic': 107,
#          'Film': 106,
#          'Electronic Component': 106,
#          'Season': 106,
#          'Legislative Body': 104,
#          'Neighborhood': 103,
#          'Color': 103,
#          'Inventor': 102,
#          'Feature': 102,
#          'BiologicalProcess': 102,
#          'Directory': 102,
#          'Male': 102,
#          'Software Company': 101,
#          'Subtype': 100,
#          'Medical': 100,
#          'AbstractEntity': 100,
#          'Virus': 98,
#          'Infrastructure': 97,
#          'Temperature': 97,
#          'Protagonist': 97,
#          'Mineral': 96,
#          'Physics': 95,
#          'Television Show': 95,
#          'AbstractConcept': 95,
#          'Social Media Platform': 94,
#          'Coach': 93,
#          'Goal': 93,
#          'Price': 93,
#          'Section': 93,
#          'Football Team': 93,
#          'Genus': 92,
#          'Item': 91,
#          'Adverb': 91,
#          'Military Unit': 90,
#          'Patients': 89,
#          'Information': 89,
#          'Length': 88,
#          'Hormone': 88,
#          'Non-profit': 87,
#          'Band': 87,
#          'Circuit Judge': 87,
#          'Family': 86,
#          'Album': 86,
#          'Airline': 86,
#          'Structure': 85,
#          'Road': 85,
#          'Rapper': 84,
#          'EntityType': 84,
#          'AnatomicalEntity': 84,
#          'Relationship': 83,
#          'Position': 82,
#          'Writer': 82,
#          'Boxer': 82,
#          'Tool': 82,
#          'Disease or Disorder': 80,
#          'Peptide': 80,
#          'Computer': 79,
#          'Numeric': 79,
#          'Producer': 78,
#          'Body Part': 78,
#          'Area': 78,
#          'Body of Water': 78,
#          'Population': 77,
#          'MusicGroup': 77,
#          'Restaurant': 76,
#          'Magazine': 76,
#          'Fictional Character': 76,
#          'Methodology': 76,
#          'Sports Competition': 76,
#          'Community': 75,
#          'Healthcare': 75,
#          'Religious Organization': 75,
#          'Framework': 75,
#          'Administrative Division': 75,
#          'Chemical compound': 75,
#          'Mathematical': 75,
#          'Expression': 74,
#          'Network': 74,
#          'Cytokine': 74,
#          'River': 74,
#          'Hardware': 74,
#          'Age Group': 74,
#          'LocationType': 73,
#          'Monetary Value': 73,
#          'Geographical Area': 73,
#          'Fact': 72,
#          'Article': 72,
#          'Code': 72,
#          'Victim': 72,
#          'Colon': 72,
#          'Venue': 71,
#          'Education': 71,
#          'Aircraft': 71,
#          'Ion': 71,
#          'Broadcaster': 70,
#          'Decade': 70,
#          'Physical Entity': 70,
#          'Publisher': 70,
#          'Clothing': 70,
#          'Search Engine': 70,
#          'Governor': 69,
#          'Set': 69,
#          'Political': 69,
#          'Textual Entity': 69,
#          'Racer': 69,
#          'Answer': 68,
#          'Cancer': 67,
#          'Historical Event': 67,
#          'Medical condition': 67,
#          'Physical object': 66,
#          'Actress': 65,
#          'Quantifier': 65,
#          'Citation': 65,
#          'Conference': 65,
#          'Biological Substance': 65,
#          'Comparison': 64,
#          'Field of Study': 64,
#          'Genre': 64,
#          'Township': 64,
#          'Museum': 64,
#          'Smartphone': 64,
#          'Acronym': 64,
#          'Religion': 63,
#          'GroupOfPeople': 63,
#          'Punctuation': 63,
#          'ChemicalCompound': 63,
#          'Plural Noun': 62,
#          'Law Enforcement Agency': 62,
#          'Birth Date': 62,
#          'Biological entity': 62,
#          'Competition': 62,
#          'Commodity': 62,
#          'Executive': 61,
#          'Subordinating Conjunction': 60,
#          'Car Model': 60,
#          'User': 60,
#          'Particle': 60,
#          'Keyword': 59,
#          'News Organization': 59,
#          'Time Period': 59,
#          'Ethnicity': 59,
#          'Gas': 59,
#          'Researcher': 59,
#          'Deity': 59,
#          'Physical Property': 59,
#          ' Person ': 59,
#          'Medical procedure': 58,
#          'C++': 58,
#          'Law Enforcement': 57,
#          'Disease or Condition': 57,
#          'ProductType': 57,
#          'Medical Treatment': 57,
#          'Insurance Company': 57,
#          'Market': 57,
#          'Anatomy': 57,
#          'Child': 56,
#          'Journal': 56,
#          'Shape': 56,
#          'JobTitle': 56,
#          'Environment': 56,
#          'Corporation': 56,
#          'SoftwareApplication': 56,
#          'Suspect': 56,
#          'Direction': 55,
#          'HealthCondition': 55,
#          'Instruction': 55,
#          'Hotel': 55,
#          'Financial Institution': 55,
#          'Airport': 55,
#          'Basketball Team': 55,
#          'Module': 55,
#          'Bird': 54,
#          'Communication': 54,
#          ' Organization ': 54,
#          'Spacecraft': 54,
#          'Surname': 54,
#          'Platform': 53,
#          'Electronic Device': 53,
#          'Century': 53,
#          'Appellee': 53,
#          'Symbol': 53,
#          'Superhero': 53,
#          'Size': 53,
#          'Individual': 53,
#          'Appellate Court': 53,
#          'Discipline': 53,
#          'Software Version': 53,
#          'Ship': 52,
#          'DayOfWeek': 52,
#          'Academic': 52,
#          'Research Institute': 52,
#          'Law Firm': 52,
#          'Miscellaneous': 52,
#          'SoftwareComponent': 52,
#          'Soccer Team': 52,
#          'Reason': 51,
#          'Cell Type': 51,
#          'Assessment': 51,
#          'Legal': 51,
#          'Strain': 51,
#          'Record Label': 51,
#          'Opinion': 50,
#          'Molecule': 50,
#          'Geographical Region': 50,
#          'Manager': 50,
#          'Party': 50,
#          'Matrix': 50,
#          'Antibiotic': 50,
#          'Creature': 50,
#          'Data Structure': 49,
#          'Group of People': 49,
#          'Frequency': 49,
#          'Therapy': 49,
#          'Legislative body': 48,
#          'Mother': 48,
#          'Sentence': 48,
#          'Authors': 48,
#          'Distance': 48,
#          'Settlement': 48,
#          'Doctor': 48,
#          'Highway': 48,
#          'Biological substance': 48,
#          'Plural': 47,
#          'Employer': 47,
#          'Institution': 47,
#          'General': 47,
#          'Photographer': 47,
#          'Body part': 47,
#          'Array': 47,
#          'PersonGroup': 47,
#          'Fungus': 47,
#          'Legal Entity': 46,
#          'Football Manager': 46,
#          'Election': 46,
#          'News Website': 46,
#          'Geographical location': 46,
#          'Cell line': 45,
#          'Musical Group': 45,
#          'Part': 45,
#          'Lipid': 45,
#          'Blogger': 45,
#          'Signal': 45,
#          'Broadcasting Company': 45,
#          'Brain Structure': 45,
#          'Medical Device': 44,
#          'PoliticalEntity': 44,
#          'Football League': 44,
#          'Label': 44,
#          'Municipality': 44,
#          'List': 44,
#          'Novel': 44,
#          'Music Genre': 44,
#          'Cricketer': 44,
#          'Anatomical Entity': 44,
#          'URL': 43,
#          'Geographical Location': 43,
#          'Religious Figure': 43,
#          'Address': 43,
#          'Electrical Component': 43,
#          'Neurological': 43,
#          'Beverage': 43,
#          'LOCATION': 43,
#          'Entrepreneur': 42,
#          'Composer': 42,
#          'GovernmentalBody': 42,
#          'Biological': 42,
#          'Professor': 42,
#          'Music': 42,
#          'Disorder': 42,
#          'Mouse': 42,
#          'Utility': 42,
#          'Wrestler': 42,
#          'Debtor': 42,
#          'Nutrient': 42,
#          'Network Protocol': 42,
#          'Equipment': 41,
#          'Theory': 41,
#          'LegalEntity': 41,
#          'Biological Structure': 41,
#          'Legal Document': 41,
#          'Resource': 41,
#          'Behavior': 41,
#          'Domain': 41,
#          'Mathematics': 41,
#          'Antibody': 41,
#          'Polymer': 41,
#          'Businessperson': 41,
#          'Political Event': 41,
#          ' Location': 41,
#          'Energy Company': 41,
#          'Central Bank': 41,
#          'Car': 41,
#          'Expression of Ideas': 40,
#          'Labor Union': 40,
#          'Comedian': 40,
#          'Attorney': 40,
#          'Religious Group': 40,
#          'Version Control System': 40,
#          'Physical Phenomenon': 40,
#          'QuotationMark': 40,
#          'Medical Equipment': 40,
#          'AbstractItem': 40,
#          'MonetaryAmount': 39,
#          'Professional': 39,
#          'Semiconductor': 39,
#          'Radio Station': 39,
#          'Crime': 39,
#          'Criminal': 38,
#          'Webpage': 38,
#          'Dimension': 38,
#          'Protocol': 38,
#          'Unit': 38,
#          'Software Component': 38,
#          'Designer': 38,
#          'Content Management System': 38,
#          'League': 37,
#          'Problem': 37,
#          'Engine': 37,
#          'Society': 37,
#          'Report': 37,
#          'Political Union': 37,
#          'Political Division': 37,
#          'Outcome': 37,
#          'Abstract Entity': 37,
#          'PhysicalEntity': 37,
#          'Space Agency': 37,
#          'Healthcare Provider': 37,
#          'Mountain': 37,
#          'Entity Type': 37,
#          'MedicalTerm': 37,
#          'Textual Role': 37,
#          'Law': 36,
#          'Stadium': 36,
#          'Energy': 36,
#          'Geographical Feature': 36,
#          'School District': 36,
#          'Regulator': 36,
#          'Political Group': 36,
#          'Horse': 36,
#          'Quarterback': 36,
#          'Legal Proceeding': 36,
#          'Historical Figure': 36,
#          'Immune Cell': 36,
#          'Exam': 36,
#          'Mount point offset': 36,
#          'Automaker': 35,
#          'Agreement': 35,
#          'Microorganism': 35,
#          'Standard': 35,
#          'Medium': 35,
#          'Date Range': 35,
#          'Festival': 35,
#          'Algorithm': 35,
#          'Race': 35,
#          'Olympic Games': 35,
#          'Finance': 35,
#          'Weapon': 35,
#          'Local Government': 35,
#          'Mathematician': 35,
#          'Government Official': 35,
#          'Medical_condition': 35,
#          'Chemical_Substance': 35,
#          'Other': 35,
#          'Father': 34,
#          'Term': 34,
#          'Political party': 34,
#          'Growth Factor': 34,
#          'War': 34,
#          'Legal Case': 34,
#          'Column': 34,
#          'Song': 34,
#          'Message': 34,
#          'Concentration': 34,
#          'Room': 34,
#          'Result': 34,
#          'ORGANIZATION': 34,
#          'Historical': 34,
#          'Package': 34,
#          'Campaign': 34,
#          'Real Estate': 34,
#          'Church': 34,
#          'Political Organization': 34,
#          'BiologicalSubstance': 34,
#          'SoftwareVersion': 33,
#          'Commune': 33,
#          'Parasite': 33,
#          'Association': 33,
#          'Surgical Procedure': 33,
#          'Monarch': 33,
#          'Degree': 33,
#          'Petitioner': 33,
#          'Characteristic': 33,
#          'Alias': 33,
#          'Fastener': 33,
#          'Calcium-activated neutral protease': 33,
#          'Open Parenthesis': 33,
#          'Death Date': 32,
#          'Television Channel': 32,
#          'Legal Concept': 32,
#          'Case Number': 32,
#          'Range': 32,
#          'Police Department': 32,
#          'Architect': 32,
#          'Economist': 32,
#          'Attorney General': 32,
#          'Cell Line': 32,
#          'Negation': 32,
#          'God': 32,
#          'Government Program': 32,
#          'BaseballPlayer': 32,
#          'Web Browser': 31,
#          'Patient Group': 31,
#          'Television Program': 31,
#          'Utility Company': 31,
#          'Military Branch': 31,
#          'Investigation': 31,
#          'Editor': 31,
#          'Planet': 31,
#          'Singer-songwriter': 31,
#          'Breed': 31,
#          'Historical Period': 31,
#          'Sequence': 31,
#          'Vector': 31,
#          'Deceased Person': 31,
#          'Pathogen': 31,
#          'Phenomenon': 31,
#          'Insect': 31,
#          '': 31,
#          'Text Entity': 31,
#          'Fish': 30,
#          'Consumer': 30,
#          'Solution': 30,
#          'Head of State': 30,
#          'MediaOutlet': 30,
#          'Art': 30,
#          'Risk': 30,
#          'Version': 30,
#          'Physical quantity': 30,
#          'Rank': 30,
#          'Celebrity': 30,
#          'Findings': 30,
#          'Reference': 30,
#          'Railway Company': 30,
#          'Column Name': 30,
#          'Art Form': 29,
#          'Royalty': 29,
#          'Financial Instrument': 29,
#          'Regulation': 29,
#          'Businessman': 29,
#          'Mass': 29,
#          'Distribution': 29,
#          'Design': 29,
#          'Autoimmune Disease': 29,
#          'Ethnic Group': 29,
#          'Theme': 29,
#          'Terrorist Group': 29,
#          'Owner': 29,
#          'Deceased': 29,
#          'Telecommunications': 29,
#          'Medical treatment': 29,
#          'Organelle': 29,
#          'Book Title': 29,
#          'Employee': 29,
#          'Suburb': 29,
#          'Work': 29,
#          'Chemical Compound': 29,
#          'Spider': 29,
#          'Email': 28,
#          'Startup': 28,
#          'Phone Number': 28,
#          'Stock Exchange': 28,
#          'Research Institution': 28,
#          'Mental Disorder': 28,
#          'Prime Minister': 28,
#          'Medical Imaging': 28,
#          'Geographical Entity': 28,
#          'Spouse': 28,
#          'Friend': 28,
#          'Political Ideology': 28,
#          'Co-founder': 28,
#          'Table': 28,
#          'Discography': 28,
#          'Computing': 28,
#          'International Organization': 28,
#          'DATE': 28,
#          'Place': 28,
#          'Poet': 28,
#          ' Country': 28,
#          'Cellular process': 28,
#          'Electronic': 28,
#          'Laser': 28,
#          'Philosopher': 28,
#          'Leo': 28,
#          'Appliance': 27,
#          'License': 27,
#          'Alcohol': 27,
#          'Foundation': 27,
#          'Commenter': 27,
#          'Diet': 27,
#          'Political Campaign': 27,
#          'Auxiliary Verb': 27,
#          'News Channel': 27,
#          'Performance': 27,
#          'Food Company': 27,
#          'Holiday': 27,
#          'Division': 27,
#          ' Politician': 27,
#          'Force': 27,
#          'Cricket Team': 27,
#          'AnatomicalStructure': 27,
#          'Online Retailer': 27,
#          'Government Building': 27,
#          'Biological Macromolecule': 27,
#          'NGO': 27,
#          'Golf Tour': 27,
#          'Dictator': 27,
#          'SQL Statement': 27,
#          'Programming Concept': 26,
#          'Integrated Development Environment': 26,
#          'Scientific': 26,
#          'Reader': 26,
#          'Law Enforcement Officer': 26,
#          'Electronic component': 26,
#          'Retail': 26,
#          'Ratio': 26,
#          'Dish': 26,
#          'Cell type': 26,
#          'Residential': 26,
#          'Teacher': 26,
#          'Religious': 26,
#          'Nanomaterial': 26,
#          'Religious Institution': 26,
#          'DataType': 26,
#          'Natural Disaster': 26,
#          'Space Station': 26,
#          'Infant': 26,
#          'Neuron': 26,
#          'Effect': 26,
#          'Astronaut': 26,
#          'Parser': 26,
#          'Cells': 25,
#          'Fruit': 25,
#          'Development': 25,
#          'Healthcare Facility': 25,
#          'Mayor': 25,
#          'Biological Property': 25,
#          'Chairman': 25,
#          'Committee': 25,
#          'Exchange': 25,
#          'Media Organization': 25,
#          'Birthdate': 25,
#          'Namespace': 25,
#          'Golfer': 25,
#          'Amino acid': 25,
#          'Volume': 25,
#          'Metadata': 25,
#          'Anime': 25,
#          'LegalConcept': 25,
#          'Esports Team': 25,
#          'Game Developer': 25,
#          'Day of the Week': 25,
#          'Tax': 25,
#          'Racing Team': 25,
#          'Car Brand': 25,
#          'Syndrome': 25,
#          'Receptor': 24,
#          'Case': 24,
#          'Developer': 24,
#          'Think Tank': 24,
#          'Storage': 24,
#          'Geopolitical Entity': 24,
#          'Group of people': 24,
#          'Skill': 24,
#          'File Format': 24,
#          'Era': 24,
#          'Military Base': 24,
#          'Professionals': 24,
#          'SoftwareArtifact': 24,
#          'NFL Team': 24,
#          'Text Editor': 24,
#          'Solvent': 24,
#          'Rule': 24,
#          'Dog': 24,
#          'Goddess': 24,
#          'Medical concept': 24,
#          'Mechanical Component': 24,
#          'Building Clients': 24,
#          'No subtype': 24,
#          'Proteins': 23,
#          'Extract': 23,
#          'Adhesive': 23,
#          'College': 23,
#          'Medicine': 23,
#          'Organization Subtype': 23,
#          'Religious Text': 23,
#          'Power': 23,
#          'Human': 23,
#          'Promotion': 23,
#          'JavaScript Test Runner': 23,
#          'Television': 23,
#          'Race Track': 23,
#          'Person Group': 23,
#          'Surface': 23,
#          'Battery': 23,
#          'TextEntity': 23,
#          'Pope': 23,
#          'Nickname': 23,
#          'Insulator': 23,
#          'Mental Health Condition': 23,
#          'Computer Component': 23,
#          'Mathematical Concept': 23,
#          'Peak': 23,
#          'Calcium ion': 23,
#          'EventEmitter': 23,
#          'Patent Application': 22,
#          'Media outlet': 22,
#          'Social Media': 22,
#          'Human Rights': 22,
#          'Activist': 22,
#          'Operator': 22,
#          'Scientific Name': 22,
#          'Policy': 22,
#          'Electronic device': 22,
#          'Economic System': 22,
#          'Media Franchise': 22,
#          'Respondent': 22,
#          'Independent Variable': 22,
#          'Series': 22,
#          'Filmmaker': 22,
#          ' Organization': 22,
#          'Football club': 22,
#          'Hockey Player': 22,
#          'Job': 22,
#          'Cat': 22,
#          'Glass': 22,
#          'Musical Instrument': 22,
#          'Prefecture': 22,
#          'Lake': 22,
#          'Unincorporated community': 22,
#          'Play': 22,
#          'Quarter': 22,
#          'Subsidiary': 22,
#          'Grain': 22,
#          'Parent': 22,
#          'GeopoliticalEntity': 22,
#          'Parameter': 22,
#          'Technical Term': 22,
#          'End Date': 22,
#          'Field of study': 22,
#          'Bishop': 22,
#          'Proposition': 22,
#          'Apache': 22,
#          'Transporter': 22,
#          'MedicalEntity': 22,
#          'Plant_property': 22,
#          'Boolean': 21,
#          'College Basketball Team': 21,
#          'Robot': 21,
#          'State Highway': 21,
#          'Ideology': 21,
#          'Geographical': 21,
#          'Station': 21,
#          'Environmental Issue': 21,
#          'Music Group': 21,
#          'Regulatory Body': 21,
#          'Jurisdiction': 21,
#          'Image': 21,
#          'Port number delimiter': 21,
#          'Monetary Amount': 21,
#          'Historian': 21,
#          'Residence': 21,
#          'Order': 21,
#          'Real Estate Company': 21,
#          'Training': 21,
#          'Engineer': 21,
#          'Court of Appeals': 21,
#          'Military Personnel': 21,
#          'Historical Entity': 21,
#          'Scalar': 21,
#          'Digital Currency': 21,
#          'Patent Number': 21,
#          'Disease or disorder': 21,
#          'Charity': 21,
#          'Tissue': 21,
#          'Hockey Team': 21,
#          'Detective': 21,
#          'Mountain Range': 21,
#          'Railway': 21,
#          'Disaster': 21,
#          'Soccer Player': 21,
#          'Football Coach': 21,
#          'Nerve': 21,
#          'Herb': 21,
#          'Data Storage': 21,
#          'Professional Association': 21,
#          'Body Fluid': 21,
#          'Nut': 21,
#          'Vehicle component': 21,
#          'App': 21,
#          'Game Console': 21,
#          'Layer': 21,
#          'Vessel': 21,
#          'Government Ministry': 21,
#          'Dollar Sign': 21,
#          'Keyboard': 21,
#          'Vampire': 21,
#          'Military Organization': 21,
#          'EntityType.OBJECT': 21,
#          'Intensity': 20,
#          'Economy': 20,
#          'Historical Site': 20,
#          'Tumor': 20,
#          'Waste': 20,
#          'Weight': 20,
#          'Act': 20,
#          'Geological Feature': 20,
#          'Fuel': 20,
#          'Issue': 20,
#          'Count': 20,
#          'Agent': 20,
#          'Billionaire': 20,
#          'PhysicalProperty': 20,
#          'Database Table': 20,
#          'Oil Company': 20,
#          'Competitor': 20,
#          'Prosecutor': 20,
#          'Quote': 20,
#          'Certification': 20,
#          'Educational Program': 20,
#          'Spice': 20,
#          'GeographicalFeature': 20,
#          'Level': 20,
#          'Web Hosting Provider': 20,
#          'Body': 20,
#          'Explorer': 20,
#          'Carbohydrate': 20,
#          'Pro Wrestler': 20,
#          'Scholar': 20,
#          'Analysis': 20,
#          'Soccer Club': 20,
#          'Supernatural Being': 20,
#          'Command': 20,
#          'Anatomical entity': 20,
#          'Terminal': 20,
#          'Government Entity': 20,
#          'PersonName': 20,
#          'Physical entity': 20,
#          'User Interface': 20,
#          'Star': 20,
#          'Farm': 20,
#          'Physical phenomenon': 20,
#          'HTML Tag': 20,
#          'Military Equipment': 20,
#          'Display': 20,
#          'capacitor': 20,
#          'Software Artifact': 20,
#          'Auxiliary': 20,
#          'Version Number': 20,
#          'Advertising Agency': 19,
#          'Minister': 19,
#          'Speech': 19,
#          'Internal Combustion Engine': 19,
#          'Science': 19,
#          ...})

# %%
print_sample_text(pile_mistral,seed=25,joined = False)
# Out:
# ['#', '!', '/', 'usr', '/', 'bin', '/', 'env', 'python', 'PACKAGE', '=', "'", 'orbit_pantilt', "'", 'import', 'roslib', ';', 'roslib', '.', 'load_manifest', '(', 'PACKAGE', ')', 'from', 'math', 'import', 'pi', 'from', 'driver_base', '.', 'msg', 'import', 'SensorLevels', 'from', 'dynamic_reconfigure', '.', 'parameter_generator', 'import', '*', 'gen', '=', 'ParameterGenerator', '(', ')', '#', 'gen', '.', 'add', '(', '"', 'max_range', '"', ',', 'double_t', ',', 'SensorLevels', '.', 'RECONFIGURE_RUNNING', ',', '#', '"', 'max_range', 'corresponding', 'to', 'max', 'sensor', 'output', '"', ',', '5', '.', '0', ',', '0', '.', '0', ',', '20', '.', '0', ')', 'gen', '.', 'add', '(', '"', 'pan_reset', '"', ',', 'bool_t', ',', 'SensorLevels', '.', 'RECONFIGURE_RUNNING', ',', '"', 'reset', 'pan', 'position', '"', ',', 'False', ')', 'gen', '.', 'add', '(', '"', 'tilt_reset', '"', ',', 'bool_t', ',', 'SensorLevels', '.', 'RECONFIGURE_RUNNING', ',', '"', 'reset', 'tilt', 'position', '"', ',', 'False', ')', 'gen', '.', 'add', '(', '"', 'pan', '"', ',', 'int_t', ',', 'SensorLevels', '.', 'RECONFIGURE_RUNNING', ',', '"', 'pan', 'position', '"', ',', '0', ',', '-', '94', ',', '94', ')', 'gen', '.', 'add', '(', '"', 'tilt', '"', ',', 'int_t', ',', 'SensorLevels', '.', 'RECONFIGURE_RUNNING', ',', '"', 'tilt', 'position', '"', ',', '0', ',', '-', '51', ',', '51', ')', 'exit', '(', 'gen', '.', 'generate', '(', 'PACKAGE', ',', '"', 'orbit_pantilt', '"', ',', '"', 'OrbitPanTilt', '"', ')', ')']
#
# ['2000', 'NCAA', 'Division', 'I', 'Men', "'", 's', 'Tennis', 'Championships', 'The', '2000', 'NCAA', 'Division', 'I', 'Men', "'", 's', 'Tennis', 'Championships', 'were', 'the', '54th', 'annual', 'championships', 'to', 'determine', 'the', 'national', 'champions', 'of', 'NCAA', 'Division', 'I', 'men', "'", 's', 'singles', ',', 'doubles', ',', 'and', 'team', 'collegiate', 'tennis', 'in', 'the', 'United', 'States', '.', 'Stanford', 'defeated', 'Virginia', 'Commonwealth', 'in', 'the', 'championship', 'final', ',', '4', '–', '0', ',', 'to', 'claim', 'the', 'Cardinal', "'", 's', 'seventeenth', 'team', 'national', 'title', '.', 'Host', 'sites', 'This', 'year', "'", 's', 'tournaments', 'were', 'played', 'at', 'the', 'Dan', 'Magill', 'Tennis', 'Complex', 'at', 'the', 'University', 'of', 'Georgia', 'in', 'Athens', ',', 'Georgia', '.', 'The', 'men', "'", 's', 'and', 'women', "'", 's', 'tournaments', 'would', 'not', 'be', 'held', 'at', 'the', 'same', 'site', 'until', '2006', '.', 'See', 'also', 'NCAA', 'Division', 'II', 'Tennis', 'Championships', '(', 'Men', ',', 'Women', ')', 'NCAA', 'Division', 'III', 'Tennis', 'Championships', '(', 'Men', ',', 'Women', ')', 'References', 'External', 'links', 'List', 'of', 'NCAA', 'Men', "'", 's', 'Tennis', 'Champions', 'Category', ':', 'NCAA', 'Division', 'I', 'tennis', 'championships', 'Ncaa', 'Division', 'I', 'Tennis', 'Championships', 'Ncaa', 'Division', 'I', 'Tennis', 'Championships']
#
# ['According', 'to', 'prolific', 'GTA', 'tipster', ',', 'Funmw2', 'aka', '@', 'TezFunz2', ',', 'the', 'forthcoming', 'DLC', 'will', 'be', 'released', 'as', 'part', 'of', 'the', 'Christmas', 'update', 'along', 'the', 'lines', 'of', 'Lowriders', 'DLC', 'which', 'included', 'necessary', 'game', 'content', 'for', 'the', 'Halloween', 'update', '.', 'The', 'tipster', 'also', 'suggests', 'the', 'idea', 'of', 'adding', 'a', 'new', 'Slasher', 'adversary', 'mode', 'in', 'North', 'Yankton', 'with', 'the', 'release', 'of', 'Lowriders', '2', 'aka', 'Christmas', 'update', '.', 'With', 'the', 'recent', 'leaks', ',', 'R', '*', 'might', 'create', 'another', 'update', 'for', 'christmas', '.', '.', 'A', 'new', 'Slasher', 'adversary', 'mode', 'in', 'North', 'yankton', 'would', 'be', 'great', '!', 'Rockstar', 'is', 'expected', 'to', 'turn', 'on', 'the', 'Tunables', 'feature', 'for', 'unlocking', 'the', 'hidden', 'content', 'for', 'the', 'next', 'DLC', 'sometime', 'after', 'releasing', 'the', 'second', 'instalment', 'of', 'Lowiders', 'update', '.', 'In', 'other', 'words', ',', 'we', 'could', 'see', 'the', 'integration', 'of', 'two', 'DLCs', 'into', 'one', 'update', 'as', 'was', 'the', 'case', 'with', 'Halloween', 'game', 'files', 'being', 'included', 'with', 'the', 'Lowrider', 'DLC', '.', 'Moving', 'on', 'to', 'the', 'most', 'probable', 'release', 'dates', 'for', 'the', 'Lowriders', '2', 'update', ',', 'Ross', 'hints', 'at', 'an', 'early', 'or', 'mid-December', 'release', '.', 'The', 'Festive', 'Surprise', '3', '.', '0', 'aka', 'Christmas', 'DLC', 'is', 'expected', 'to', 'release', 'soon', 'after', 'the', 'second', 'DLC', 'release', 'for', 'Lowriders', ',', 'which', 'is', 'likely', 'to', 'introduce', 'a', 'couple', 'of', 'new', 'cars', ',', 'masks', 'and', 'T-Shirts', 'along', 'with', 'a', 'bunch', 'of', 'new', 'feature', 'additions', 'such', 'as', 'Snow', ',', 'Christmas', 'tree', 'and', 'tunable', 'or', 'customisable', 'apartments', 'in', 'GTA', 'Online', '.']
#
# ['Human', 'body', 'may', 'produce', 'bacteria', '.', '"', 'Human', 'body', 'may', 'produce', 'bacteria', '"', 'proposes', 'that', 'human', 'body', 'may', 'produce', 'bacteria', 'and', 'represent', 'an', 'independent', 'source', 'of', 'infections', 'contrary', 'to', 'the', 'current', 'paradigm', 'of', 'infectious', 'disorders', 'proposed', 'by', 'Louis', 'Pasteur', 'in', '1880', '.', 'The', 'following', 'observations', 'are', 'consistent', 'with', 'this', 'hypothesis', ':', 'A', '.', 'Bidirectional', 'transformations', 'of', 'both', 'living', 'and', 'nonliving', 'things', 'have', 'been', 'commonly', 'observed', 'in', 'nature', '.', 'B', '.', 'Complex', 'multicellular', 'organisms', 'harbor', 'the', 'necessary', 'properties', 'to', 'produce', 'bacteria', '(', 'water', ',', 'nitrogen', 'and', 'oxygen', ')', '.', 'C', '.', 'Physical', 'laws', 'suggest', 'any', 'previously', 'observed', 'phenomenon', 'or', 'action', 'will', 'occur', 'again', '(', 'life', 'began', 'on', 'earth', ';', 'a', 'non', 'living', 'thing', ')', '.', 'D', '.', 'Animal', 'muscle', 'cells', 'may', 'generate', 'energy', '(', 'fermentation', ')', '.', 'E', '.', 'Sterilized', 'food', 'products', '(', 'i', '.', 'e', '.', 'boiled', 'eggs', ')', ',', 'may', 'produce', 'bacteria', 'and', 'fungus', 'under', 'special', 'conditions', 'and', 'without', 'any', 'exposure', 'to', 'foreign', 'living', 'cells', '.', '"', 'Human', 'body', 'may', 'produce', 'bacteria', '"', 'may', 'challenge', 'the', 'current', 'medical', 'paradigm', 'that', 'views', 'human', 'infectious', 'disorders', 'as', 'the', 'exclusive', 'causative', 'byproducts', 'of', 'invading', 'foreign', 'cells', '.', 'It', 'may', 'also', 'introduce', 'new', 'avenues', 'to', 'treat', 'infectious', 'disorders', '.']
#
# ['TRON', 'has', 'not', 'gained', 'a', 'lot', 'in', 'terms', 'of', 'price', 'since', 'the', 'beginning', 'of', 'the', 'year', '.', 'The', 'greatest', 'high', 'achieved', 'was', 'on', 'January', '5th', 'this', 'year', ',', 'when', 'the', 'price', 'was', 'at', '$', '0', '.', '2547', '.', 'Since', 'then', ',', 'TRX', 'has', 'declared', 'many', 'cool', 'updates', 'and', 'a', 'lot', 'of', 'other', 'features', 'via', 'Justin', ',', 'but', 'the', 'prices', 'have', 'not', 'improved', 'a', 'lot', '.', 'This', 'is', 'a', 'whale', 'alert', 'which', 'might', 'prove', 'to', 'be', 'crucial', 'in', 'days', 'to', 'come', '.', 'What', 'do', 'you', 'think', 'of', 'this', ':', 'Many', 'look', 'at', 'TRON', 'as', 'the', 'new', 'savior', 'in', 'a', 'world', 'headed', 'by', 'decentralization', '.', 'Among', 'those', 'is', 'long-time', 'TRX', 'enthusiast', 'Misha', 'Lederman', '.', 'He', 'tweeted', ':', 'This', 'month', 'is', 'slated', 'to', 'be', '“', 'Big', '”', 'for', 'BitTorrent', '.', 'On', '25th', ',', 'he', 'is', 'to', 'meet', 'up', 'with', 'Warren', 'Buffett', 'and', 'Charlie', 'Lee', 'for', 'a', 'charity', 'lunch', 'that', 'he', 'had', 'purchased', 'with', 'millions', '.', 'This', 'is', 'a', 'move', 'made', 'in', 'order', 'to', 'accelerate', 'investor', 'interest', 'in', 'the', 'field', 'of', 'blockchain', 'technology', '.', 'Before', 'as', 'well', ',', 'some', 'haters', 'have', 'changed', 'their', 'minds', '.', 'Peter', 'Schiff', 'admitted', 'to', 'holding', 'a', 'few', 'hundred', 'worths', 'a', 'short', 'while', 'back', '.', 'This', 'proves', 'that', 'the', 'tide', 'is', 'turning', ',', 'and', '2020', 'may', 'be', 'a', 'huge', 'year', 'for', 'many', 'top', 'altcoins', 'in', 'the', 'market', '.', 'T-3', 'days', 'until', '#', 'BitTorrentSpeed', 'is', 'available', 'for', '100', 'million', 'users', 'around', 'the', 'world', '!']
#
# ['The', 'Way', 'of', 'the', 'Disciple', 'Now', 'is', 'the', 'time', 'to', 'embrace', 'the', 'gospel', 'of', 'Jesus', 'Christ', ',', 'become', 'His', 'disciples', ',', 'and', 'walk', 'in', 'His', 'way', '.', 'Today', 'is', 'the', 'day', 'the', 'Christian', 'world', 'traditionally', 'calls', 'Palm', 'Sunday', '.', 'You', 'will', 'remember', 'that', 'it', 'was', 'on', 'that', 'Sunday', 'nearly', '2', ',', '000', 'years', 'ago', 'that', 'Jesus', 'Christ', 'entered', 'the', 'city', 'of', 'Jerusalem', 'during', 'the', 'final', 'week', 'of', 'His', 'mortal', 'life', '.', '1', 'In', 'fulfillment', 'of', 'Zechariah', '’', 's', 'ancient', 'prophecy', ',', '2', 'He', 'rode', 'in', 'on', 'a', 'donkey', ',', 'and', 'as', 'He', 'did', 'so', ',', 'a', 'great', 'multitude', 'came', 'out', 'to', 'greet', 'the', 'Master', 'and', 'carpeted', 'the', 'path', 'before', 'Him', 'with', 'palm', 'leaves', ',', 'flowering', 'branches', ',', 'and', 'even', 'their', 'own', 'garments', '.', 'As', 'He', 'approached', ',', 'they', 'cried', ',', '“', 'Blessed', 'be', 'the', 'King', 'that', 'cometh', 'in', 'the', 'name', 'of', 'the', 'Lord', '”', '3', 'and', '“', 'Hosanna', 'to', 'the', 'Son', 'of', 'David', '.', '”', '4', 'Perhaps', 'the', 'disciples', 'thought', 'this', 'was', 'a', 'turning', 'point', '—', 'the', 'moment', 'when', 'the', 'Jewish', 'world', 'would', 'finally', 'recognize', 'Jesus', 'as', 'the', 'long-awaited', 'Messiah', '.', 'But', 'the', 'Savior', 'understood', 'that', 'many', 'of', 'the', 'shouts', 'of', 'praise', 'and', 'acclamation', 'would', 'be', 'temporary', '.', 'He', 'knew', 'that', 'soon', 'He', 'would', 'ascend', 'to', 'the', 'Mount', 'of', 'Olives', 'and', 'there', ',', 'alone', 'in', 'Gethsemane', ',', 'take', 'upon', 'Himself', 'the', 'sins', 'of', 'the', 'world', '.', 'The', 'Gospel', 'of', 'Jesus', 'Christ', 'It', 'is', 'fitting', 'that', 'during', 'the', 'week', 'from', 'Palm', 'Sunday', 'to', 'Easter', 'morning', 'we', 'turn', 'our', 'thoughts', 'to', 'Jesus', 'Christ', ',', 'the', 'source', 'of', 'light', ',', 'life', ',', 'and', 'love', '.']
#
# ['KSKZ', 'KSKZ', '(', '98', '.', '1', 'FM', ')', 'is', 'a', 'radio', 'station', 'broadcasting', 'a', 'Contemporary', 'Hit', 'Radio', 'format', '.', 'Licensed', 'to', 'Copeland', ',', 'Kansas', ',', 'United', 'States', ',', 'the', 'station', 'serves', 'the', 'Dodge', 'City', 'and', 'Garden', 'City', 'areas', '.', 'The', 'station', 'is', 'currently', 'owned', 'by', 'Mark', 'Yearout', ',', 'through', 'licensee', 'Southwind', 'Broadcasting', ',', 'LLC', ',', 'and', 'features', 'programming', 'from', 'ABC', 'Radio', '.', 'References', 'External', 'links', 'SKZ', 'Category', ':', 'Hot', 'adult', 'contemporary', 'radio', 'stations', 'in', 'the', 'United', 'States', 'Category', ':', 'Radio', 'stations', 'established', 'in', '1977']
#
# ['501', 'So', '.', '2d', '715', '(', '1987', ')', 'Daniel', 'Alphonse', 'FLEMING', 'and', 'Allstate', 'Insurance', 'Company', ',', 'Appellants', ',', 'v', '.', 'Catherine', 'A', '.', 'HILL', ',', 'Personal', 'Representative', 'of', 'the', 'Estate', 'of', 'Thomas', 'James', 'Dunn', ',', 'Jr', '.', ';', 'American', 'States', 'Insurance', 'Company', ';', 'and', 'Government', 'Employees', 'Insurance', 'Company', ',', 'Appellees', '.', 'Nos', '.', '86-237', ',', '86-263', '.', 'District', 'Court', 'of', 'Appeal', 'of', 'Florida', ',', 'Fifth', 'District', '.', 'January', '29', ',', '1987', '.', '*', '716', 'Marybeth', 'McDonald', 'of', 'Cooper', ',', 'Rissman', '&', 'Weisberg', ',', 'P', '.', 'A', '.', ',', 'Orlando', ',', 'for', 'appellant', 'Daniel', 'Alphonse', 'Fleming', '.', 'Francis', 'J', '.', 'Carroll', ',', 'Jr', '.', ',', 'of', 'Smalbein', ',', 'Eubank', ',', 'Johnson', ',', 'Rosier', '&', 'Bussey', ',', 'P', '.', 'A', '.', ',', 'Daytona', 'Beach', ',', 'for', 'appellant', 'Allstate', 'Ins', '.', 'Co', '.', 'Clifford', 'D', '.', 'Edelston', 'of', 'Gurney', '&', 'Handley', ',', 'P', '.', 'A', '.', ',', 'Orlando', ',', 'for', 'appellee', 'Government', 'Employees', 'Ins', '.', 'Co', '.', 'F', '.', 'Scott', 'Pendley', 'of', 'Dean', ',', 'Ringers', ',', 'Morgan', '&', 'Lawton', ',', 'P', '.', 'A', '.', 'Orlando', ',', 'for', 'appellee', 'American', 'States', 'Ins', '.', 'Co', '.', 'No', 'appearance', 'for', 'appellee', 'Catherine', 'A', '.', 'Hill', '.', 'COBB', ',', 'Judge', '.', 'This', 'appeal', 'arises', 'out', 'of', 'a', 'petition', 'for', 'declaratory', 'relief', 'filed', 'by', 'appellee', ',', 'American', 'States', 'Insurance', 'Company', '(', 'American', 'States', ')', ',', 'a', 'cross-claim', '/', 'counterclaim', 'for', 'declaratory', 'relief', 'filed', 'by', 'Government', 'Employees', 'Insurance', 'Company', '(', 'GEICO', ')', ',', 'and', 'a', 'wrongful', 'death', 'action', 'against', 'Daniel', 'Fleming', 'filed', 'by', 'appellee', 'Catherine', 'A', '.', 'Hill', ',', 'as', 'personal', 'representative', 'of', 'the', 'Estate', 'of', 'Thomas', 'Dunn', '.', 'The', 'material', 'facts', 'surrounding', 'the', 'incident', 'and', 'the', 'actions', 'below', 'are', 'not', 'in', 'dispute', '.']
#
# ['Green', 'Lake', '(', 'Seattle', ')', 'Green', 'Lake', 'is', 'a', 'freshwater', 'lake', 'in', 'north', 'central', 'Seattle', ',', 'Washington', ',', 'within', 'Green', 'Lake', 'Park', '.', 'The', 'park', 'is', 'surrounded', 'by', 'the', 'Green', 'Lake', 'neighborhood', 'to', 'the', 'north', 'and', 'east', ',', 'the', 'Wallingford', 'neighborhood', 'to', 'the', 'south', ',', 'the', 'Phinney', 'Ridge', 'neighborhood', 'to', 'the', 'west', ',', 'and', 'Woodland', 'Park', 'to', 'the', 'southwest', '.', 'It', 'is', 'a', 'glacial', 'lake', ',', 'its', 'basin', 'having', 'been', 'dug', '50', ',', '000', 'years', 'ago', 'by', 'the', 'Vashon', 'glacier', ',', 'which', 'also', 'created', 'Lake', 'Washington', ',', 'Union', ',', 'Bitter', 'and', 'Haller', 'Lakes', '.', 'History', 'Green', 'Lake', 'was', 'given', 'its', 'modern', 'name', 'by', 'David', 'Phillips', ',', 'who', 'surveyed', 'the', 'area', 'in', 'September', '1855', 'for', 'the', 'United', 'States', 'Surveyor', 'General', '.', 'His', 'first', 'notes', 'referred', 'to', 'it', 'as', '"', 'Lake', 'Green', '"', 'because', 'even', 'in', 'its', 'natural', 'state', 'the', 'lake', 'is', 'prone', 'to', 'algae', 'blooms', '.', 'The', 'Duwamish', 'called', 'it', 'dxWTLusH', ',', 'a', 'Lushootseed', 'word', 'of', 'unknown', 'meaning', '.', 'The', 'lake', 'has', 'a', 'surface', 'area', 'of', ',', 'a', 'mean', 'depth', 'of', '13', 'feet', '(', '3', '.', '8', 'm', ')', ',', 'and', 'a', 'maximum', 'depth', 'of', '30', 'feet', '(', '9', '.', '1', 'm', ')', '.', 'The', 'lake', 'has', 'been', 'dredged', 'in', 'order', 'to', 'maintain', 'its', 'depth', '.', 'Green', 'Lake', 'lacks', 'both', 'surface', 'water', 'inflows', 'and', 'outflows', '.', 'It', 'once', 'drained', 'into', 'Lake', 'Washington', 'via', 'Ravenna', 'Creek', ',', 'but', 'in', '1911', 'the', 'water', 'level', 'was', 'lowered', 'by', '7', 'feet', '(', '2', '.', '1', 'm', ')', 'to', 'create', 'parkland', ',', 'causing', 'the', 'creek', 'to', 'dry', 'up', 'between', 'Green', 'Lake', 'and', 'Cowen', 'Park', '.']
#
# ['Lilly', 'PulitzerRyder', 'Shift', 'This', 'printed', 'dress', 'is', 'bra-friendly', 'and', 'has', 'a', 'notched', 'neckline', 'with', 'beading', 'details', '.', 'It', 'is', 'very', 'light', 'weight', 'and', 'perfect', 'when', 'planning', 'a', 'summer', 'getaway', ',', 'be', 'sure', 'to', 'pack', 'an', 'easy', 'printed', 'shift', ',', 'you', "'", 'll', 'be', 'surprised', 'how', 'many', 'times', 'you', 'wear', 'it', '.', 'Shift', 'dress', 'features', 'a', 'top', 'applied', 'lace', 'around', 'notch', 'and', 'down', 'center', 'front', '.']

# %% [markdown]
# ## mutliconer_v2

# %%
german_data = load_dataset('MultiCoNER/multiconer_v2', 'German (DE)')
# Out:
# Downloading data:   0%|          | 0.00/1.27M [00:00<?, ?B/s]
# Downloading data:   0%|          | 0.00/78.2k [00:00<?, ?B/s]
# Downloading data:   0%|          | 0.00/2.59M [00:00<?, ?B/s]
# Generating train split:   0%|          | 0/9785 [00:00<?, ? examples/s]
# Generating validation split:   0%|          | 0/512 [00:00<?, ? examples/s]
# Generating test split:   0%|          | 0/20145 [00:00<?, ? examples/s]

# %%
german_data['train'].features['ner_tags_index'].feature
# Out:
# ClassLabel(names=['O', 'B-Facility', 'I-Facility', 'B-OtherLOC', 'I-OtherLOC', 'B-HumanSettlement', 'I-HumanSettlement', 'B-Station', 'I-Station', 'B-VisualWork', 'I-VisualWork', 'B-MusicalWork', 'I-MusicalWork', 'B-WrittenWork', 'I-WrittenWork', 'B-ArtWork', 'I-ArtWork', 'B-Software', 'I-Software', 'B-OtherCW', 'I-OtherCW', 'B-MusicalGRP', 'I-MusicalGRP', 'B-PublicCorp', 'I-PublicCorp', 'B-PrivateCorp', 'I-PrivateCorp', 'B-OtherCorp', 'I-OtherCorp', 'B-AerospaceManufacturer', 'I-AerospaceManufacturer', 'B-SportsGRP', 'I-SportsGRP', 'B-CarManufacturer', 'I-CarManufacturer', 'B-TechCORP', 'I-TechCORP', 'B-ORG', 'I-ORG', 'B-Scientist', 'I-Scientist', 'B-Artist', 'I-Artist', 'B-Athlete', 'I-Athlete', 'B-Politician', 'I-Politician', 'B-Cleric', 'I-Cleric', 'B-SportsManager', 'I-SportsManager', 'B-OtherPER', 'I-OtherPER', 'B-Clothing', 'I-Clothing', 'B-Vehicle', 'I-Vehicle', 'B-Food', 'I-Food', 'B-Drink', 'I-Drink', 'B-OtherPROD', 'I-OtherPROD', 'B-Medication/Vaccine', 'I-Medication/Vaccine', 'B-MedicalProcedure', 'I-MedicalProcedure', 'B-AnatomicalStructure', 'I-AnatomicalStructure', 'B-Symptom', 'I-Symptom', 'B-Disease', 'I-Disease'], id=None)

# %% [markdown]
# ## our Anon-dataset

# %%
anon_datapath = f"anon_data/"

# %%
with open(os.path.join(anon_datapath,"complete_ner_data.json"),'r') as f:
    data = json.load(f)

# %%
explore_dataset(data)
# Out:
# length : 124089
# avg tokenized text length : 1767.450749059143
# max tokenized text length : 93834
# min tokenized text length : 0
# labels : {'location', 'person', 'organization'}

# %%
get_label_dict(data)
# Out:
# Counter({'person': 986117, 'organization': 135304, 'location': 38122})

# %%
print_sample_text(data,joined = False)
# Out:
# ['Participants', 'à', 'la', 'procédure', 'Maria', 'Berisha', ',', 'représenté', 'par', 'Me', 'Jillian', 'Fauguel', ',', 'avocate', ',', 'recourant', ',', 'contre', 'Elena', 'Stettler', ',', 'représentée', 'par', 'Me', 'Jean-Christophe', 'Oberson', ',', 'avocat', ',', 'intimée', '.', 'Objet', 'divorce', '(', 'contribution', 'd', "'", 'entretien', 'en', 'faveur', 'des', 'enfants', 'mineurs', ')', ',', 'recours', 'contre', 'l', "'", 'arrêt', 'de', 'la', 'Ie', 'Cour', 'd', "'", 'appel', 'civil', 'du', 'Tribunal', 'cantonal', 'de', 'l', "'", 'Etat', 'de', 'Fribourg', 'du', '8', 'juin', '2018', '(', '101', '2017', '317', ')', '.', 'Faits', ':', 'A', '.', 'Le', '24', 'juillet', '2017', ',', 'le', 'Tribunal', 'civil', 'de', 'l', "'", 'arrondissement', 'de', 'la', 'Glâne', 'a', 'prononcé', 'le', 'divorce', 'de', 'Maria', 'Berisha', '(', '1979', ')', 'et', 'Elena', 'Stettler', '(', '1982', ')', '(', '1', ')', '.', 'Il', 'a', 'notamment', 'maintenu', 'l', "'", 'autorité', 'parentale', 'conjointe', 'sur', 'les', 'enfants', 'Albert', 'Tresch', ',', 'née', 'en', '2006', ',', 'et', 'Laura', 'Fetaj', ',', 'né', 'en', '2011', '(', '2', ')', ',', 'la', 'garde', 'étant', 'confiée', 'à', 'la', 'mère', '(', '3', ')', ',', 'le', 'père', 'bénéficiant', 'd', "'", 'un', 'large', 'droit', 'de', 'visite', 'à', 'raison', 'd', "'", 'une', 'semaine', 'sur', 'deux', 'du', 'jeudi', 'soir', 'au', 'dimanche', '18h00', ',', 'une', 'semaine', 'sur', 'deux', 'du', 'jeudi', 'à', 'la', 'sortie', 'de', 'l', "'", 'école', 'au', 'vendredi', 'matin', 'à', 'l', "'", 'entrée', 'à', 'l', "'", 'école', 'ainsi', 'qu', "'", 'un', 'autre', 'jour', 'de', 'la', 'semaine', ',', 'variable', ',', 'de', 'préférence', 'quand', 'la', 'maman', 'travaille', ',', 'de', 'la', 'sortie', 'de', 'l', "'", 'école', 'au', 'lendemain', 'à', 'l', "'", 'entrée', 'de', 'l', "'", 'école', ',', 'ainsi', 'que', 'la', 'moitié', 'des', 'vacances', 'scolaires', '(', '4', ')', '.', 'L', "'", 'époux', 'a', 'été', 'astreint', 'à', 'contribuer', 'à', 'l', "'", 'entretien', 'de', 'ses', 'enfants', 'par', 'le', 'versement', 'de', '435', 'fr', '.', 'par', 'mois', 'pour', 'chacun', 'd', "'", 'eux', '(', '5', ')', ',', 'étant', 'précisé', 'que', 'cette', 'pension', 'ne', 'couvrait', 'pas', 'leur', 'entretien', 'convenable', ',', 'qui', 'a', 'également', 'été', 'fixé', '(', '6', ')', '.', 'Il', 'a', 'été', 'pris', 'acte', 'que', 'les', 'époux', 'ont', 'renoncé', 'à', 'toute', 'contribution', 'entre', 'eux', '(', '7', ')', '.', 'Par', 'arrêt', 'du', '8', 'juin', '2018', ',', 'la', 'Ie', 'Cour', 'd', "'", 'appel', 'civil', 'du', 'Tribunal', 'cantonal', 'du', 'canton', 'de', 'Fribourg', 'a', 'partiellement', 'admis', 'l', "'", 'appel', 'formé', 'par', 'l', "'", 'époux', 'et', 'rejeté', 'l', "'", 'appel', 'joint', 'formé', 'par', 'l', "'", 'épouse', '.', 'Elle', 'a', 'réformé', 'cette', 'décision', ',', 'en', 'ce', 'sens', 'que', 'la', 'contribution', 'due', 'par', 'l', "'", 'époux', 'pour', 'l', "'", 'entretien', 'de', 'ses', 'enfants', 'est', 'fixée', 'à', '300', 'fr', '.', 'par', 'enfant', 'jusqu', "'", 'à', 'l', "'", 'âge', 'de', '12', 'ans', 'révolus', ',', 'puis', 'à', '450', 'fr', '.', 'par', 'enfant', 'dès', 'l', "'", 'âge', 'de', '12', 'ans', 'révolus', 'jusqu', "'", 'à', 'la', 'majorité', ',', 'l', "'", 'art', '.', '277', 'al', '.', '2', 'CC', 'étant', 'réservé', ',', 'les', 'pensions', 'étant', 'payables', 'd', "'", 'avance', 'le', 'premier', 'de', 'chaque', 'mois', 'et', 'portant', 'intérêt', 'à', '5', '%', 'l', "'", 'an', 'dès', 'chaque', 'échéance', 'en', 'cas', 'de', 'retard', '.', 'Le', 'chiffre', '6', 'du', 'premier', 'jugement', 'a', 'été', 'supprimé', '.', 'B', '.', 'Par', 'acte', 'du', '11', 'juillet', '2018', ',', 'Maria', 'Berisha', 'exerce', 'un', 'recours', 'en', 'matière', 'civile', 'au', 'Tribunal', 'fédéral', '.', 'Il', 'conclut', 'à', 'la', 'réforme', 'de', 'l', "'", 'arrêt', 'cantonal', ',', 'en', 'ce', 'sens', 'que', 'les', 'pensions', 'mensuelles', 'sont', 'fixées', 'à', '150', 'fr', '. ...
#
# ['Parteien', 'Soundadvice', 'AG', ',', 'Beschwerdeführerin', ',', 'gegen', 'Leon', 'Neyer', ',', 'vertreten', 'durch', 'Rechtsanwalt', 'Peter', 'A', '.', 'Iten', ',', 'Beschwerdegegner', ',', 'Staatsanwaltschaft', 'des', 'Kantons', 'Zug', ',', '6301', 'Zug', ',', 'Beschwerdegegnerin', '.', 'Gegenstand', 'Aufhebung', 'einer', 'Nichtanhandnahmeverfügung', ',', 'Beschwerde', 'gegen', 'das', 'Urteil', 'des', 'Obergerichts', 'des', 'Kantons', 'Zug', ',', 'Justizkommission', ',', 'Strafrechtliche', 'Kammer', ',', 'vom', '27', '.', 'Mai', '2009', '.', 'Der', 'Präsident', 'zieht', 'in', 'Erwägung', ':', '1', '.', 'Mit', 'Verfügung', 'vom', '11', '.', 'Februar', '2009', 'nahm', 'die', 'Staatsanwaltschaft', 'des', 'Kantons', 'Zug', 'eine', 'vom', 'Beschwerdegegner', 'verlangte', 'Strafuntersuchung', 'gegen', 'die', 'Beschwerdeführerin', 'betreffend', 'Hehlerei', 'nicht', 'an', 'die', 'Hand', '.', 'Die', 'Vorinstanz', 'hiess', 'im', 'angefochtenen', 'Entscheid', 'eine', 'dagegen', 'gerichtete', 'kantonale', 'Beschwerde', 'des', 'Beschwerdegegners', 'gut', '.', 'Sie', 'hob', 'die', 'Nichtanhandnahmeverfügung', 'auf', 'und', 'wies', 'die', 'Staatsanwaltschaft', 'an', ',', 'eine', 'Strafuntersuchung', 'gegen', 'die', 'Beschwerdeführerin', 'bzw', '.', 'deren', 'verantwortliche', 'Personen', 'zu', 'eröffnen', '.', 'Dagegen', 'wendet', 'sich', 'die', 'Beschwerdeführerin', 'mit', 'Beschwerde', 'in', 'Strafsachen', 'ans', 'Bundesgericht', '.', 'Die', 'Beschwerde', 'ans', 'Bundesgericht', 'ist', 'zulässig', 'gegen', 'Entscheide', ',', 'die', 'das', 'kantonale', 'Verfahren', 'abschliessen', '(', 'Art', '.', '90', 'BGG', ')', '.', 'Diese', 'Voraussetzung', 'ist', 'im', 'vorliegenden', 'Fall', 'klarerweise', 'nicht', 'erfüllt', '.', 'Dass', 'einer', 'der', 'Ausnahmefälle', 'von', 'Art', '.', '93', 'Abs', '.', '1', 'BGG', 'gegeben', 'wäre', ',', 'macht', 'die', 'Beschwerdeführerin', 'nicht', 'geltend', '(', 'zu', 'den', 'Begründungsanforderungen', 'Urteil', '5A_472', '/', '2007', 'vom', '12', '.', 'November', '2007', ',', 'E', '.', '2', '.', '3', ')', '.', 'Dies', 'springt', 'auch', 'nicht', 'in', 'die', 'Augen', ',', 'da', 'die', 'Frage', ',', 'ob', 'sich', 'die', 'Beschwerdeführerin', 'strafbar', 'gemacht', 'haben', 'könnte', ',', 'im', 'kantonalen', 'Verfahren', 'umstritten', 'war', '.', 'Auf', 'die', 'Beschwerde', 'ist', 'im', 'Verfahren', 'nach', 'Art', '.', '108', 'BGG', 'nicht', 'einzutreten', '.', '2', '.', 'Die', 'Gerichtskosten', 'sind', 'der', 'Beschwerdeführerin', 'aufzuerlegen', '(', 'Art', '.', '66', 'Abs', '.', '1', 'BGG', ')', '.', 'Dem', 'Beschwerdegegner', 'ist', 'keine', 'Entschädigung', 'auszurichten', ',', 'weil', 'er', 'im', 'Verfahren', 'vor', 'Bundesgericht', 'keine', 'Umtriebe', 'hatte', '.', 'Demnach', 'erkennt', 'der', 'Präsident', ':', '1', '.', 'Auf', 'die', 'Beschwerde', 'wird', 'nicht', 'eingetreten', '.', '2', '.', 'Die', 'Gerichtskosten', 'von', 'Fr', '.', '800', '.', '-', '-', 'werden', 'der', 'Beschwerdeführerin', 'auferlegt', '.', '3', '.', 'Dieses', 'Urteil', 'wird', 'den', 'Parteien', 'und', 'dem', 'Obergericht', 'des', 'Kantons', 'Zug', ',', 'Justizkommission', ',', 'Strafrechtliche', 'Kammer', ',', 'schriftlich', 'mitgeteilt', '.', 'Lausanne']
#
# ['Tribunale', 'federale', 'Tribunal', 'federal', '{', 'T', '0', '/', '2', '}', '4A_285', '/', '2007', '/', 'ech', 'Arrêt', 'du', '8', 'novembre', '2007', 'Ire', 'Cour', 'de', 'droit', 'civil', 'Composition', 'MM', '.', 'et', 'Mmes', 'les', 'juges', 'Corboz', ',', 'président', ',', 'Klett', ',', 'Rottenberg', 'Liatowitsch', ',', 'Kolly', 'et', 'Kiss', '.', 'Greffier', ':', 'M', '.', 'Thélin', '.', 'Parties', 'Valérie', 'Steiger', ',', 'demanderesse', 'et', 'recourante', ',', 'représentée', 'par', 'Me', 'Henri', 'Nanchen', ',', 'contre', 'Benben', 'Creative', 'Design', 'SA', ',', 'défenderesse', 'et', 'intimée', ',', 'représentée', 'par', 'Me', 'Franco', 'Villa', '.', 'Objet', 'contrat', 'd', "'", 'assurance', ';', 'clause', 'bénéficiaire', 'recours', 'en', 'matière', 'civile', 'contre', 'l', "'", 'arrêt', 'rendu', 'le', '8', 'juin', '2007', 'par', 'la', 'Chambre', 'civile', 'de', 'la', 'Cour', 'de', 'justice', 'du', 'canton', 'de', 'Genève', '.', 'Faits', ':', 'A', '.', 'Aurora', 'Pantieri', 'et', 'Marina', 'Kolica', 'se', 'sont', 'mariés', 'en', '1965', '.', 'Ils', 'eurent', 'deux', 'enfants', ',', 'Kim', 'Brencic', 'en', '1967', 'et', 'Kim', 'Kronig', 'en', '1975', '.', 'Par', 'testament', 'daté', 'du', '23', 'avril', '1981', ',', 'Aurora', 'Pantieri', 'a', 'attribué', 'l', "'", 'usufruit', 'de', 'tous', 'ses', 'biens', 'à', 'son', 'épouse', 'et', 'il', 'a', 'institué', 'pour', 'héritiers', 'les', 'deux', 'enfants', ',', 'à', 'parts', 'égales', 'entre', 'eux', '.', 'Dès', '1986', ',', 'séparé', 'de', 'son', 'épouse', ',', 'Aurora', 'Pantieri', 'a', 'noué', 'une', 'relation', 'intime', 'avec', 'Valérie', 'Steiger', ';', 'il', 'vivait', 'désormais', 'avec', 'elle', '.', 'Il', 'est', 'décédé', 'le', '20', 'novembre', '2001', 'à', 'l', "'", 'âge', 'de', 'soixante-et-un', 'ans', '.', 'B', '.', 'Le', '6', 'avril', '1994', ',', 'la', 'société', 'd', "'", 'assurances', 'Lanturno', 'Management', 'SA', 'a', 'émis', 'une', 'police', 'n', '°', '9400172', 'relative', 'à', 'une', 'assurance', 'mixte', 'survie', 'et', 'décès', 'sur', 'deux', 'têtes', '.', 'Aurora', 'Pantieri', 'était', 'le', 'preneur', 'd', "'", 'assurance', '.', 'Celui-ci', 'et', 'Valérie', 'Steiger', 'étaient', 'l', "'", 'un', 'et', 'l', "'", 'autre', 'assurés', '.', 'L', "'", 'assureur', 'promettait', 'une', 'rente', 'mensuelle', 'de', '1', "'", '881', 'fr', '.', 'dès', 'le', '31', 'mars', '2005', 'et', 'aussi', 'longtemps', 'que', 'vivrait', 'l', "'", 'un', 'ou', 'l', "'", 'autre', 'des', 'assurés', '.', 'Un', 'capital', 'de', 'restitution', ',', 'décroissant', 'en', 'fonction', 'des', 'prestations', 'périodiques', 'déjà', 'versées', ',', 'était', 'dû', 'au', 'décès', 'des', 'deux', 'assurés', '.', 'Ceux-ci', 'étaient', 'désignés', 'bénéficiaires', 'de', 'la', 'rente', ';', 'trois', 'autres', 'personnes', 'étaient', 'désignées', 'bénéficiaires', 'du', 'capital', 'de', 'restitution', '.', 'L', "'", 'assureur', 'percevait', 'une', 'prime', 'unique', 'au', 'montant', 'de', '300', "'", '000', 'francs', '.', 'Par', 'la', 'suite', ',', 'Lanturno', 'Management', 'SA', 'a', 'fusionné', 'avec', 'la', 'société', 'Benben', 'Creative', 'Design', 'SA', 'qui', 'lui', 'a', 'succédé', '.', 'Le', '23', 'septembre', '2002', ',', 'après', 'le', 'décès', 'de', 'leur', 'père', 'et', 'mari', ',', 'Kim', 'Brencic', ',', 'Kim', 'Kronig', 'et', 'Marina', 'Kolica', 'ont', 'communiqué', 'à', 'l', "'", 'assureur', 'qu', "'", 'ils', 'désignaient', 'cette', 'dernière', 'pour', 'succéder', 'au', 'défunt', 'en', 'qualité', 'de', 'preneur', 'd', "'", 'assurance', '.', 'Marina', 'Kolica', 'se', 'désignait', 'elle-même', 'en', 'qualité', 'de', 'bénéficiaire', 'de', 'la', 'rente', ';', 'elle', 'désignait', 'les', 'enfants', 'en', 'qualité', 'de', 'bénéficiaires', 'du', 'capital', 'de', 'restitution', '.', 'Elle', 'exerçait', 'par', 'ailleurs', 'le', 'droit', 'au', 'rachat', ';', 'en', 'conséquence', ',', 'l', "'", 'assureur', 'remboursa', '300', "'", '000', 'fr', '.', 'aux', 'héritiers', 'et', 'il', 'émit ...
#
# ['Parteien', ',', 'dem', 'Sozialversicherungsgericht', 'des', 'Kantons', 'Zürich', 'und', 'dem', 'Bundesamt', 'für', 'Sozialversicherungen', 'schriftlich', 'mitgeteilt', '.', 'Luzern', ',', '5', '.', 'November', '2020', 'Im', 'Namen', 'der', 'II', '.', 'sozialrechtlichen', 'Abteilung', 'des', 'Schweizerischen', 'Bundesgerichts', 'Der', 'Präsident', ':', 'Parrino', 'Die', 'Gerichtsschreiberin', ':', 'Stanger']
#
# ['Parteien', ',', 'dem', 'Versicherungsgericht', 'des', 'Kantons', 'St', '.', 'Gallen', 'und', 'dem', 'Bundesamt', 'für', 'Sozialversicherungen', 'schriftlich', 'mitgeteilt', '.', 'Luzern', ',', '22', '.', 'Mai', '2012', 'Im', 'Namen', 'der', 'II', '.', 'sozialrechtlichen', 'Abteilung', 'des', 'Schweizerischen', 'Bundesgerichts', 'Der', 'Präsident', ':', 'Meyer', 'Der', 'Gerichtsschreiber', ':', 'Scartazzini']
#
# ['Parteien', ',', 'dem', 'Versicherungsgericht', 'des', 'Kantons', 'Solothurn', 'und', 'dem', 'Bundesamt', 'für', 'Sozialversicherungen', 'schriftlich', 'mitgeteilt', '.', 'Luzern', ',', '2', '.', 'Dezember', '2011', 'Im', 'Namen', 'der', 'I', '.', 'sozialrechtlichen', 'Abteilung', 'des', 'Schweizerischen', 'Bundesgerichts', 'Das', 'präsidierende', 'Mitglied', ':', 'Leuzinger', 'Der', 'Gerichtsschreiber', ':', 'Jancar']
#
# ['Bundesgericht', 'Tribunal', 'fédéral', 'Tribunale', 'federale', 'Tribunal', 'federal', '{', 'T', '0', '/', '2', '}', '5A_447', '/', '2011', 'Urteil', 'vom', '12', '.', 'September', '2011', 'II', '.', 'zivilrechtliche', 'Abteilung', 'Besetzung', 'Bundesrichterin', 'Escher', ',', 'präsidierendes', 'Mitglied', ',', 'Gerichtsschreiber', 'Füllemann', '.', 'Verfahrensbeteiligte', 'Antonia', 'Dahlmann', ',', 'Beschwerdeführerin', ',', 'gegen', 'Betreibungsamt', 'Josef', 'Rubichi', '.', 'Gegenstand', 'Pfändungsvollzug', ',', 'Beschwerde', 'nach', 'Art', '.', '72', 'ff', '.', 'BGG', 'gegen', 'den', 'Entscheid', 'vom', '23', '.', 'Mai', '2011', 'der', 'Aufsichtsbehörde', 'Schuldbetreibung', 'und', 'Konkurs', 'Basel-Landschaft', '.', 'Nach', 'Einsicht', 'in', 'die', 'Beschwerde', 'nach', 'Art', '.', '72', 'ff', '.', 'BGG', 'gegen', 'den', 'Entscheid', 'vom', '23', '.', 'Mai', '2011', 'der', 'Aufsichtsbehörde', 'Schuldbetreibung', 'und', 'Konkurs', 'Basel-Landschaft', '(', '420', '11', '81', 'vo1', ')', ',', 'in', 'Erwägung', ',', 'dass', 'die', 'Beschwerdeführerin', 'mit', 'Nachfristansetzung', 'gemäss', 'Art', '.', '62', 'Abs', '.', '3', 'BGG', 'vom', '18', '.', 'August', '2011', 'unter', 'Androhung', 'des', 'Nichteintretens', 'bei', 'Säumnis', 'aufgefordert', 'worden', 'ist', ',', 'den', '(', 'ihr', 'mit', 'Verfügung', 'vom', '4', '.', 'Juli', '2011', 'auferlegten', ',', 'jedoch', 'nicht', 'eingegangenen', ')', 'Kostenvorschuss', 'von', 'Fr', '.', '300', '.', '-', '-', 'innerhalb', 'einer', 'nicht', 'erstreckbaren', 'Nachfrist', 'von', '7', 'Tagen', 'seit', 'der', 'am', '26', '.', 'August', '2011', 'erfolgten', 'Zustellung', 'dem', 'Bundesgericht', 'in', 'bar', 'zu', 'zahlen', 'oder', 'zu', 'Gunsten', 'der', 'Bundesgerichtskasse', '(', 'Postkonto', '10-674-3', ')', 'entweder', 'an', 'einem', 'Schalter', 'der', 'Schweizerischen', 'Post', 'zu', 'übergeben', 'oder', '(', 'bei', 'Erteilung', 'eines', 'Zahlungsauftrags', 'an', 'die', 'Post', 'oder', 'an', 'eine', 'Bank', ')', 'einem', 'in', 'der', 'Schweiz', 'befindlichen', 'Post', '-', 'bzw', '.', 'Bankkonto', 'der', 'Beschwerde', 'führenden', 'Partei', 'oder', 'ihres', 'Vertreters', 'zu', 'belasten', '(', 'Art', '.', '48', 'Abs', '.', '4', 'BGG', ')', 'und', 'ausserdem', '(', 'bei', 'Erteilung', 'eines', 'Zahlungsauftrags', ')', 'der', 'Bundesgerichtskasse', 'innerhalb', 'von', '10', 'Tagen', 'seit', 'Ablauf', 'der', 'nicht', 'erstreckbaren', 'Nachfrist', 'eine', 'Bestätigung', 'der', 'Postfinance', 'bzw', '.', 'der', 'Bank', 'einzureichen', ',', 'wonach', 'der', 'Vorschussbetrag', 'fristgerecht', 'dem', 'Post', '-', 'bzw', '.', 'Bankkonto', 'belastet', 'worden', 'ist', ',', 'dass', 'die', 'Beschwerdeführerin', 'den', 'Kostenvorschuss', 'auch', 'innerhalb', 'der', 'Nachfrist', 'weder', 'bei', 'der', 'Bundesgerichtskasse', 'in', 'bar', 'geleistet', 'noch', 'zu', 'deren', 'Gunsten', 'an', 'einem', 'Postschalter', 'übergeben', 'und', 'auch', 'nicht', 'den', '(', 'für', 'den', 'Fall', 'eines', 'Zahlungsauftrags', ')', 'ihr', 'obliegenden', 'Nachweis', 'der', 'rechtzeitigen', 'Vorschussleistung', 'durch', 'Belastungsbestätigung', 'erbracht', 'hat', ',', 'weshalb', 'androhungsgemäss', 'gestützt', 'auf', 'Art', '.', '62', 'Abs', '.', '3', 'BGG', 'im', 'Verfahren', 'nach', 'Art', '.', '108', 'Abs', '.', '1', 'lit', '.', 'a', 'BGG', 'auf', 'die', 'Beschwerde', 'nicht', 'einzutreten', 'ist', 'und', 'die', 'Beschwerdeführerin', 'kostenpflichtig', 'wird', '(', 'Art', '.', '66', 'Abs', '.', '1', 'BGG', ')', ',', 'erkennt', 'das', 'präsidierende', 'Mitglied', ':', '1', '.', 'Auf', 'die', 'Beschwerde', 'wird', 'nicht', 'eingetreten', '.', '2', '.', 'Die', 'Gerichtskosten', 'von', 'Fr', '.', '200', '.', '-', '-', '-', 'werden', 'der', 'Beschwerdeführerin', 'auferlegt', '.', '3', '.', 'Dieses', 'Urteil', 'wird', 'der', 'Beschwerdeführerin', ',', 'dem', 'Betreibungsamt', 'Josef', 'Rubichi', 'und', 'der', 'Aufsichtsbehörde', 'Schuldbetreibung', 'und', 'Konkurs', 'Basel-Landschaft', 'schriftlich', 'mitgete ...
#
# ['Parteien', 'Ifechukwu', 'Longhi', ',', 'Beschwerdeführer', ',', 'vertreten', 'durch', 'Rechtsanwalt', 'Reto', 'Gasser', ',', 'gegen', 'Staatsanwaltschaft', 'des', 'Kantons', 'Solothurn', ',', 'Barfüssergasse', '28', ',', 'Postfach', '157', ',', '4502', 'Solothurn', '.', 'Gegenstand', 'Sicherheitshaft', ',', 'Beschwerde', 'gegen', 'das', 'Urteil', 'vom', '26', '.', 'Oktober', '2009', 'des', 'Haftgerichts', 'des', 'Kantons', 'Solothurn', '.', 'Sachverhalt', ':', 'A', '.', 'Die', 'Staatsanwaltschaft', 'des', 'Kantons', 'Solothurn', 'führt', 'ein', 'Strafverfahren', 'gegen', 'den', 'deutschen', 'Staatsangehörigen', 'Ifechukwu', 'Longhi', 'wegen', 'des', 'Verdachts', 'des', 'gewerbsmässigen', 'Betrugs', ',', 'der', 'qualifizierten', 'Geldwäscherei', 'und', 'der', 'Urkundenfälschung', '.', 'Am', '12', '.', 'Oktober', '2008', 'begab', 'sich', 'Ifechukwu', 'Longhi', 'von', 'Deutschland', 'nach', 'Solothurn', 'und', 'stellte', 'sich', 'den', 'Strafverfolgungsbehörden', '.', 'Gleichentags', 'wurde', 'er', 'in', 'Untersuchungshaft', 'versetzt', '.', 'Diese', 'wurde', 'seither', 'mehrmals', 'verlängert', '.', 'Am', '21', '.', 'Oktober', '2009', 'erhob', 'die', 'Staatsanwaltschaft', 'Anklage', 'beim', 'Richteramt', 'Olten-Gösgen', '.', 'Gleichzeitig', 'beantragte', 'sie', 'beim', 'Haftgericht', 'des', 'Kantons', 'Solothurn', 'die', 'Anordnung', 'von', 'Sicherheitshaft', '.', 'Mit', 'Urteil', 'vom', '26', '.', 'Oktober', '2009', 'ordnete', 'die', 'Richterin', 'des', 'Haftgerichts', 'Sicherheitshaft', 'an', '.', 'Sie', 'bejahte', 'Fluchtgefahr', '.', 'B', '.', 'Ifechukwu', 'Longhi', 'führt', 'Beschwerde', 'in', 'Strafsachen', 'mit', 'dem', 'Antrag', ',', 'das', 'Urteil', 'der', 'Haftrichterin', 'sei', 'aufzuheben', ';', 'er', 'sei', 'unverzüglich', 'aus', 'der', 'Haft', 'zu', 'entlassen', '.', 'C', '.', 'Die', 'Haftrichterin', 'beantragt', 'unter', 'Hinweis', 'auf', 'die', 'Erwägungen', 'in', 'ihrem', 'Urteil', 'die', 'Abweisung', 'der', 'Beschwerde', ',', 'soweit', 'darauf', 'einzutreten', 'sei', '.', 'Die', 'Staatsanwaltschaft', 'hat', 'sich', 'vernehmen', 'lassen', '.', 'Sie', 'beantragt', 'ebenfalls', 'die', 'Abweisung', 'der', 'Beschwerde', ',', 'soweit', 'darauf', 'einzutreten', 'sei', '.', 'D', '.', 'Ifechukwu', 'Longhi', 'hat', 'eine', 'Replik', 'eingereicht', '.', 'Er', 'hält', 'an', 'seinen', 'Anträgen', 'fest', '.', 'Erwägungen', ':', '1', '.', 'Gegen', 'den', 'angefochtenen', 'Entscheid', 'ist', 'gemäss', 'Art', '.', '78', 'Abs', '.', '1', 'BGG', 'die', 'Beschwerde', 'in', 'Strafsachen', 'gegeben', '.', 'Ein', 'kantonales', 'Rechtsmittel', 'steht', 'nicht', 'zur', 'Verfügung', '(', 'Art', '.', '47quinquies', 'Abs', '.', '4', 'der', 'Strafprozessordnung', 'vom', '7', '.', 'Juni', '1970', 'des', 'Kantons', 'Solothurn', '[', 'StPO', ';', 'BGS', '321', '.', '1', ']', ')', '.', 'Die', 'Beschwerde', 'ist', 'nach', 'Art', '.', '80', 'i', '.', 'V', '.', 'm', '.', 'Art', '.', '130', 'Abs', '.', '1', 'BGG', 'zulässig', '.', 'Der', 'Beschwerdeführer', 'ist', 'gemäss', 'Art', '.', '81', 'Abs', '.', '1', 'BGG', 'zur', 'Beschwerde', 'befugt', '.', 'Die', 'übrigen', 'Sachurteilsvoraussetzungen', 'sind', '-', 'unter', 'dem', 'folgenden', 'Vorbehalt', '(', 'E', '.', '2', ')', '-', 'ebenfalls', 'erfüllt', '.', '2', '.', 'Der', 'Beschwerdeführer', 'rügt', 'einleitend', '(', 'Beschwerde', 'S', '.', '2', 'Ziff', '.', '3', ')', ',', 'die', 'Vorinstanz', 'habe', 'den', 'Sachverhalt', 'im', 'Sinne', 'von', 'Art', '.', '97', 'Abs', '.', '1', 'BGG', 'offensichtlich', 'unrichtig', 'festgestellt', '.', 'Er', 'begründet', 'dies', 'in', 'der', 'Folge', 'jedoch', 'nicht', 'hinreichend', '(', 'zu', 'den', 'entsprechenden', 'Begründungsanforderungen', 'BGE', '133', 'II', '249', 'E', '.', '1', '.', '4', '.', '3', 'S', '.', '254', 'f', '.', ')', '.', 'Insoweit', 'kann', 'auf', 'die', 'Beschwerde', 'daher', 'nicht', 'eingetreten', 'werden', '.', '3', '.', '3', '.', '1', 'Der', 'Beschwerdeführer', 'macht', 'geltend', ',', 'der', 'angefochtene', 'Entscheid', 'verle ...
#
# ['Partecipanti', 'al', 'procedimento', 'Gianluca', 'Padlina', ',', 'Studio', 'legale', 'Sulser', 'Jelmini', 'Padlina', 'e', 'Partner', ',', 'ricorrente', ',', 'contro', '1C_670', '/', '2019', 'Consiglio', 'di', 'Stato', 'della', 'Repubblica', 'e', 'Cantone', 'Ticino', ',', 'CSt-2019', ',', 'ricorso', 'contro', 'il', 'verbale', 'di', 'accertamento', 'dei', 'risultati', 'della', 'votazione', 'di', 'ballottaggio', 'del', '17', 'novembre', '2019', 'per', 'l', "'", 'elezione', 'di', 'due', 'deputati', 'al', 'Consiglio', 'degli', 'Stati', 'per', 'il', 'Cantone', 'Ticino', ',', 'e', '1C_397', '/', '2020', 'Tribunale', 'amministrativo', 'del', 'Cantone', 'Ticino', '.', 'Oggetto', 'atti', 'preparatori', 'della', 'votazione', 'di', 'ballottaggio', 'del', '17', 'novembre', '2019per', 'l', "'", 'elezione', 'di', 'due', 'deputati', 'al', 'Consiglio', 'degli', 'Stati', 'per', 'il', 'Cantone', 'Ticino', '(', 'tempestività', 'dell', "'", 'invio', 'del', 'materiale', 'di', 'voto', 'agli', 'elettori', 'all', "'", 'estero', ')', ',', 'ricorso', 'contro', 'la', 'sentenza', 'emanata', 'il', '3', 'giugno', '2020', 'dal', 'Tribunale', 'cantonale', 'amministrativo', '(', 'incarto', '52', '.', '2019', '.', '599', ')', '.', 'Fatti', ':', 'A', '.', 'Con', 'decreto', 'del', '5', 'giugno', '2019', 'il', 'Consiglio', 'di', 'Stato', 'ha', 'convocato', 'le', 'assemblee', 'dei', 'Comuni', 'del', 'Cantone', 'per', 'domenica', '20', 'ottobre', '2019', 'per', 'eleggere', ',', 'in', 'un', 'circondario', 'unico', 'costituito', 'dall', "'", 'intero', 'Cantone', 'e', 'con', 'il', 'sistema', 'maggioritario', ',', 'due', 'deputati', 'al', 'Consiglio', 'degli', 'Stati', 'per', 'la', 'legislatura', '2019-2023', '(', 'Foglio', 'ufficiale', 'n', '.', '46', '/', '2019', 'del', '7', 'giugno', '2019', 'pag', '.', '5479', ')', '.', 'L', "'", 'Esecutivo', 'cantonale', 'ha', 'stabilito', 'che', ',', 'nel', 'caso', 'in', 'cui', 'la', 'maggioranza', 'assoluta', 'non', 'fosse', 'stata', 'raggiunta', ',', 'il', 'ballottaggio', 'si', 'sarebbe', 'tenuto', 'domenica', '17', 'novembre', '2019', '.', 'B', '.', 'Il', '20', 'ottobre', '2019', 'ha', 'avuto', 'luogo', 'il', 'primo', 'turno', ';', 'nessuno', 'dei', 'candidati', 'ha', 'raggiunto', 'la', 'maggioranza', 'assoluta', '.', 'Tre', 'candidati', 'non', 'hanno', 'conseguito', 'il', 'numero', 'di', 'voti', 'necessario', 'per', 'poter', 'partecipare', 'al', 'turno', 'di', 'ballottaggio', '(', 'FU', 'n', '.', '86', '/', '2019', 'del', '25', 'ottobre', '2019', 'pag', '.', '10122', ')', '.', 'Il', 'Governo', ',', 'accertato', 'che', 'due', 'candidati', 'avevano', 'nel', 'frattempo', 'rinunciato', 'a', 'parteciparvi', ',', 'ha', 'confermato', 'lo', 'svolgimento', 'dell', "'", 'elezione', 'per', 'domenica', '17', 'novembre', '2019', 'con', 'il', 'sistema', 'della', 'maggioranza', 'relativa', '(', 'decreto', 'del', '25', 'ottobre', '2019', ',', 'FU', 'n', '.', '87', '/', '88', 'del', '29', 'ottobre', '2019', 'pag', '.', '10245', ')', '.', 'C', '.', 'Domenica', '17', 'novembre', '2019', 'ha', 'avuto', 'luogo', 'il', 'turno', 'di', 'ballottaggio', '.', 'Mercoledì', '20', 'novembre', '2019', ',', 'il', 'Consiglio', 'di', 'Stato', 'ha', 'stabilito', 'i', 'risultati', ',', 'pubblicandoli', 'il', '22', 'novembre', 'seguente', '(', 'Foglio', 'ufficiale', 'n', '.', '94', '/', '2019', 'pag', '.', '11136', ')', '.', 'I', 'candidati', 'hanno', 'ottenuto', 'i', 'seguenti', 'voti', ':', 'Filippo', 'Lombardi', ',', '1956', ',', 'PPD', '+', 'GG', '36', "'", '423', 'Marina', 'Carobbio', 'Guscetti', ',', '1966', ',', 'PS', '36', "'", '469', 'Marco', 'Ch', 'iesa', ',', '1974', ',', 'Lega', 'dei', 'Ticinesi', '/', 'UDC', '42', "'", '548', 'Giovanni', 'Merlini', ',', '1962', ',', 'PLR', '33', "'", '278', 'Sono', 'stati', 'proclamati', 'eletti', 'Marco', 'Chiesa', 'e', 'Marina', 'Carobbio', 'Guscetti', ',', 'quest', "'", 'ultima', 'avendo', 'ottenuto', '46', 'suffragi', 'in', 'più', 'del', 'deputato', 'uscente', 'Filippo', 'Lombardi', ',', 'giunto', 'terzo', '.', ...
#
# ['Bundesgericht', 'Tribunal', 'fédéral', 'Tribunale', 'federale', 'Tribunal', 'federal', '2C_862', '/', '2008', '{', 'T', '0', '/', '2', '}', 'Arrêt', 'du', '1er', 'mai', '2009', 'IIe', 'Cour', 'de', 'droit', 'public', 'Composition', 'MM', '.', 'et', 'Mme', 'les', 'Juges', 'Müller', ',', 'Président', ',', 'Merkli', ',', 'Karlen', ',', 'Zünd', 'et', 'Aubry', 'Girardin', '.', 'Greffière', ':', 'Mme', 'Dupraz', '.', 'Parties', 'Société', 'suisse', 'de', 'radiodiffusion', 'et', 'télévision', '(', 'SSR', ')', ',', 'recourante', ',', 'représentée', 'par', 'Me', 'Jamil', 'Soussi', ',', 'avocat', ',', 'contre', 'Marco', 'Borysov', ',', 'intimé', ',', 'représenté', 'par', 'Me', 'Bernard', 'Katz', ',', 'avocat', ',', 'Objet', 'Emission', '"', 'Temps', 'présent', '"', 'intitulée', '"', 'Le', 'juge', ',', 'le', 'psy', 'et', 'l', "'", 'accusé', '"', ',', 'diffusée', 'le', '31', 'mai', '2007', ',', 'recours', 'contre', 'la', 'décision', 'de', 'l', "'", 'Autorité', 'indépendante', 'd', "'", 'examen', 'des', 'plaintes', 'en', 'matière', 'de', 'radio-télévision', 'du', '10', 'mars', '2008', '.', 'Faits', ':', 'A', '.', 'Le', '31', 'mai', '2007', ',', 'la', 'Télévision', 'suisse', 'romande', '(', 'TSR', ')', 'a', 'diffusé', ',', 'dans', 'le', 'cadre', 'de', 'l', "'", 'émission', '"', 'Temps', 'présent', '"', ',', 'un', 'reportage', 'intitulé', '"', 'Le', 'juge', ',', 'le', 'psy', 'et', 'l', "'", 'accusé', '"', '.', 'Ce', 'reportage', 'se', 'composait', 'd', "'", 'une', 'introduction', 'suivie', 'de', 'cinq', 'séquences', 'relatant', 'chacune', 'une', 'affaire', 'pénale', 'qui', 's', "'", 'était', 'déroulée', 'peu', 'auparavant', 'en', 'Suisse', 'romande', 'et', 'pour', 'laquelle', 'la', 'justice', 'avait', 'recouru', 'à', 'une', 'expertise', 'psychiatrique', 'et', 'il', 'comportait', 'une', 'conclusion', '.', 'La', 'cinquième', 'séquence', 'concernait', 'le', 'cas', 'genevois', 'd', "'", 'une', 'fillette', 'qui', 'avait', 'accusé', 'son', 'père', 'et', 'deux', 'de', 'ses', 'oncles', 'de', 'lui', 'avoir', 'fait', 'subir', 'des', 'actes', 'd', "'", 'ordre', 'sexuel', '.', 'Dans', 'le', 'cadre', 'de', 'l', "'", 'instruction', 'pénale', 'de', 'ce', 'dossier', ',', 'Marco', 'Borysov', ',', 'psychiatre', ',', 'avait', 'été', 'désigné', 'afin', 'd', "'", 'effectuer', 'une', 'seconde', 'expertise', 'psychiatrique', 'sur', 'la', 'fillette', 'et', 'avait', 'conclu', 'à', 'la', 'crédibilité', 'des', 'propos', 'de', 'l', "'", 'enfant', '.', 'Par', 'la', 'suite', ',', 'l', "'", 'enfant', 's', "'", 'était', 'rétractée', 'et', 'le', 'procès', 'avait', 'finalement', 'abouti', 'à', 'un', 'acquittement', '.', 'Le', '17', 'août', '2007', ',', 'Marco', 'Borysov', 'a', 'déposé', 'plainte', 'auprès', 'de', 'l', "'", 'Autorité', 'indépendante', 'd', "'", 'examen', 'des', 'plaintes', 'en', 'matière', 'de', 'radio-télévision', '(', 'ci-après', ':', 'l', "'", 'Autorité', 'de', 'plainte', ')', '.', 'Il', 'se', 'considérait', 'comme', 'directement', 'touché', 'par', 'la', 'présentation', 'de', 'l', "'", 'affaire', 'genevoise', ',', 'qui', 'se', 'fondait', 'selon', 'lui', 'sur', 'une', 'version', 'unilatérale', 'des', 'événements', '.', 'B', '.', 'Par', 'décision', 'du', '10', 'mars', '2008', ',', 'notifiée', 'le', '27', 'octobre', '2008', ',', 'l', "'", 'Autorité', 'de', 'plainte', 'a', 'admis', 'à', 'l', "'", 'unanimité', 'la', 'plainte', 'formée', 'par', 'Marco', 'Borysov', ',', 'dans', 'la', 'mesure', 'où', 'elle', 'était', 'recevable', '.', 'Elle', 'a', 'constaté', 'que', ',', 'dans', 'l', "'", 'émission', 'litigieuse', 'diffusée', 'le', '31', 'mai', '2007', ',', 'la', 'TSR', 'avait', 'violé', 'le', 'principe', 'de', 'la', 'présentation', 'fidèle', 'des', 'événements', 'au', 'sens', 'de', 'la', 'législation', 'en', 'matière', 'de', 'radio', 'et', 'de', 'télévision', '.', 'Elle', 'a', 'invité', 'la', 'Société', 'suisse', 'de', 'radiodiffusion', 'et', 'télévision', '(', 'SSR', ')', 'à', 'l', "'", 'informer', 'des', 'dispositions', 'prises', 'dans', 'un', 'délai', 'de',  ...

# %%
print_entities(data,neighboring=5,label='location',num_samples=20)
# Out:
# sample 1
# label=location, neighboring tokens=['procès-verbal', 'authentique', 'dressé', 'par', 'Me', 'Lotzwil', ',', 'notaire', 'à', '.', '.'], label=location, neighboring tokens=['pour', '15', '%', 'et', 'à', 'Escholzmatt-Marbach', 'SA', 'de', 'siège', 'social', 'à'], label=location, neighboring tokens=['pour', '15', '%', 'et', 'à', 'Escholzmatt-Marbach', 'S', '.', 'A', '.', ',']
# sample 2
# label=location, neighboring tokens=[], label=location, neighboring tokens=['Konkursverfahren', 'mangels', 'Aktiven', 'eingestellt', '.', 'Gibloux', 'amtete', 'ab', 'November', '2002', 'bis'], label=location, neighboring tokens=['die', 'Ausgleichskasse', 'des', 'Kantons', 'Zug', 'Gibloux', 'als', 'ehemaligen', 'Verwaltungsrat', 'der', 'konkursiten'], label=location, neighboring tokens=['der', 'Firma', '.', 'Die', 'von', 'Gibloux', 'und', 'Luana', 'Mutzner', 'hiegegen', 'erhobenen'], label=location, neighboring tokens=['.', 'B', '.', 'Die', 'von', 'Gibloux', 'gegen', 'den', 'Entscheid', 'eingereichte', 'Beschwerde'], label=location, neighboring tokens=['2007', 'ab', '.', 'C', '.', 'Gibloux', 'führt', 'Beschwerde', 'in', 'öffentlich-rechtlichen', 'Angelegenheiten']
# sample 3
# label=location, neighboring tokens=['(', 'Kläger', ')', 'beim', 'Bezirksgericht', 'Noble-Contrée', 'gegen', 'Trine', 'Ravussin', '(', 'Beklagter'], label=location, neighboring tokens=['des', 'Beklagten', 'beschränkte', 'das', 'Bezirksgericht', 'Noble-Contrée', 'das', 'Verfahren', 'zunächst', 'auf', 'die'], label=location, neighboring tokens=['Juli', '2016', 'trat', 'das', 'Bezirksgericht', 'Noble-Contrée', 'mangels', 'örtlicher', 'Zuständigkeit', 'auf', 'die'], label=location, neighboring tokens=['-', 'gemeint', 'wohl', 'das', 'Bezirksgericht', 'Noble-Contrée', '-', 'anzuweisen', ',', 'auf', 'die'], label=location, neighboring tokens=['hingegen', ',', 'dass', 'das', 'Bezirksgericht', 'Noble-Contrée', '(', 'Beklagtengerichtsstand', 'gemäss', 'Art', '.']
# sample 4
# label=location, neighboring tokens=['der', 'Emmett', 'Grigoriu', 'strasse', 'in', 'Iffwil', 'ein', 'Zimmer', 'bewohnen', 'können', 'und'], label=location, neighboring tokens=['Tess', 'Massy', 'strasse', 'xxx', 'in', 'Iffwil', 'abgeschlossen', 'mit', 'Mietbeginn', 'an', 'demselben'], label=location, neighboring tokens=['Oktober', '2015', 'habe', 'er', 'in', 'Iffwil', 'über', 'zwei', 'Wohngelegenheiten', 'verfügt', ':'], label=location, neighboring tokens=['tatsächlichen', 'Aufenthaltes', 'zu', 'Wohnzwecken', 'in', 'Iffwil', '.', '5', '.', '2', '.'], label=location, neighboring tokens=['Klage', 'über', 'zwei', 'Wohngelegenheiten', 'in', 'Iffwil', 'verfügt', 'habe', ',', 'was', 'für'], label=location, neighboring tokens=['tatsächlichen', 'Aufenthaltes', 'zu', 'Wohnzwecken', 'in', 'Iffwil', 'genüge', ',', 'nimmt', 'sie', 'nicht'], label=location, neighboring tokens=['seiner', 'Freundschaft', 'zu', 'den', 'in', 'Iffwil', 'wohnhaften', 'Beat', 'Stoll', 's', ','], label=location, neighboring tokens=['Beschwerdegegner', 'beabsichtigte', ',', 'dauerhaft', 'in', 'Iffwil', 'wohnhaft', 'zu', 'bleiben', '.', 'Er'], label=location, neighboring tokens=['Absicht', 'hatte', ',', 'dauerhaft', 'in', 'Iffwil', 'zu', 'bleiben', '.', 'Mit', 'diesen'], label=location, neighboring tokens=['Wohnungsnachbarin', ';', 'eine', 'Rückkehr', 'nach', 'Grenchen', 'sei', 'nie', 'zur', 'Diskussion', 'gestanden'], label=location, neighboring tokens=['sei', 'die', 'eheliche', 'Liegenschaft', 'in', 'Grenchen', 'für', 'die', 'Dauer', 'des', 'Getrenntlebens'], label=location, neighboring tokens=['im', 'Eheschutzverfahren', 'vor', 'dem', 'Bezirksgericht', 'Grenchen', 'habe', 'der', 'Beschwerdegegner', 'die', 'eheliche'], label=location, neighboring tokens=['Zivilkammer', ',', 'und', 'dem', 'Bezirksgericht', 'Belfaux', 'schriftlich', 'mitgeteilt', '.', 'Lausanne']
# sample 5
# label=location, neighboring tokens=['territoire', 'de', 'la', 'commune', 'de', 'Jongny', '.', 'Le', 'premier', 'nommé', 'y'], label=location, neighboring tokens=[',', 'de', 'la', 'commune', 'de', 'Jongny', 'd', "'", 'user', 'de', 'la']
# sample 6
# label=location, neighboring tokens=[')', ',', 'xxx', '(', 'Versicherungen', 'Waltenschwil', ')', ',', 'yyy', '(', 'Staat']
# sample 7
# label=location, neighboring tokens=["'", 'opposition', 'par', 'le', 'docteur', 'Welschenrohr-Gänsbrunnen', 'qui', ',', 'critiquant', 'les', 'conclusions'], label=location, neighboring tokens=['diagnostics', 'énoncés', 'par', 'le', 'docteur', 'Welschenrohr-Gänsbrunnen', '(', 'rapport', 'du', '26', 'novembre'], label=location, neighboring tokens=['rapport', 'à', 'celui', 'du', 'docteur', 'Welschenrohr-Gänsbrunnen', '(', 'détermination', 'du', '5', 'mars'], label=location, neighboring tokens=['convaincante', 'les', 'objections', 'du', 'docteur', 'Welschenrohr-Gänsbrunnen', '.', 'Elle', 'relevait', 'en', 'outre'], label=location, neighboring tokens=['l', "'", 'expertise', 'du', 'docteur', 'Welschenrohr-Gänsbrunnen', ',', 'à', 'l', "'", 'octroi'], label=location, neighboring tokens=['que', 'les', 'conclusions', 'du', 'docteur', 'Welschenrohr-Gänsbrunnen', 'ne', 'pouvaient', 'être', 'écartées', 'au'], label=location, neighboring tokens=['du', 'SMR', 'et', 'du', 'docteur', 'Welschenrohr-Gänsbrunnen', ',', 'dont', 'il', 'discute', 'explicitement'], label=location, neighboring tokens=['des', 'considérations', 'contraires', 'du', 'docteur', 'Welschenrohr-Gänsbrunnen', 'à', 'propos', 'de', 'la', 'capacité']
# sample 8
# label=location, neighboring tokens=['Fernanda', 'Hatt', ',', 'de', 'nationalité', 'Saint-George', ',', 'est', 'né', 'en', '1980'], label=location, neighboring tokens=['de', 'l', "'", 'envoyer', 'au', 'Saint-George', 'où', 'elle', 'ne', 'reverrait', 'plus']
# sample 9
# label=location, neighboring tokens=['Frau', 'Dr', '.', 'med', '.', 'St', '.', 'Margrethen', ',', 'Fachärztin', 'für', 'Neurologie', 'und']
# sample 10
# label=location, neighboring tokens=['an', 'der', 'Vasco', 'Tamò', 'in', 'Billens-Hennens', 'für', 'die', 'Schuljahre', '2018', '/'], label=location, neighboring tokens=['Mietvertrag', 'für', 'eine', 'Wohnung', 'in', 'Billens-Hennens', 'unterzeichnet', 'und', 'sich', 'somit', 'auf']
# sample 11
# label=location, neighboring tokens=['.', 'Dezember', '2004', 'im', 'Spital', 'Rümlang', 'und', 'vom', '14', '.', 'bis']
# sample 12
# label=location, neighboring tokens=['médecins', 'traitants', ',', 'les', 'docteurs', 'Port', 'et', 'Catherine', 'Fässler', ',', 'psychiatre'], label=location, neighboring tokens=['nouveaux', 'avis', 'médicaux', 'des', 'docteurs', 'Port', 'et', 'Catherine', 'Fässler', ',', 'l'], label=location, neighboring tokens=['cf', '.', 'rapport', 'du', 'docteur', 'Port', 'du', '26', 'avril', '2002', ')'], label=location, neighboring tokens=['Catherine', 'Fässler', 'que', 'le', 'docteur', 'Port', 'avaient', 'déjà', 'mis', 'en', 'évidence'], label=location, neighboring tokens=['du', '22', 'mai', '2003', 'et', 'Port', 'du', '10', 'juin', '2003', ')']
# sample 13
# label=location, neighboring tokens=['A', '.', 'En', '1974', ',', 'St', '.', 'Ursen', 'SA', '(', 'devenue', 'depuis', 'lors']
# sample 14
# label=location, neighboring tokens=['la', 'route', 'xxx', ',', 'à', 'La', 'Grande', 'Béroche', '.', 'Il', 'a', 'indiqué', 'qu'], label=location, neighboring tokens=['vive', 'allure', 'en', 'direction', 'de', 'Bühl', '.', 'Gertrud', 'Sinthathurai', 'a', 'été']
# sample 15
# label=location, neighboring tokens=['den', 'Verkauf', 'von', 'Liegenschaften', 'in', 'Waldkirch', '(', 'E', '.', '31', 'S'], label=location, neighboring tokens=['beantragte', 'Verkauf', 'der', 'Wohnung', 'in', 'Waldkirch', 'sei', 'nicht', 'dringlich', '(', 'E']
# sample 16
# label=location, neighboring tokens=['Steuerperiode', '2014', 'steuerrechtlichen', 'Wohnsitz', 'in', 'Glattfelden', ',', 'Gemeinde', 'Löhningen', '/', 'TG'], label=location, neighboring tokens=['Wohnsitz', 'in', 'Glattfelden', ',', 'Gemeinde', 'Löhningen', '/', 'TG', '.', 'Dort', 'sind']
# sample 17
# label=location, neighboring tokens=['Frau', 'Dr', '.', 'med', '.', 'Zihlschlacht-Sitterdorf', ',', 'Rheumatologie', 'FMH', ',', 'vom'], label=location, neighboring tokens=['Frau', 'Dr', '.', 'med', '.', 'Zihlschlacht-Sitterdorf', ',', 'zu', 'Recht', 'auf', 'weitere'], label=location, neighboring tokens=['Frau', 'Dr', '.', 'med', '.', 'Zihlschlacht-Sitterdorf', 'eine', 'solche', 'empfohlen', 'und', 'Dr'], label=location, neighboring tokens=['Frau', 'Dr', '.', 'med', '.', 'Zihlschlacht-Sitterdorf', 'eine', 'Neuanmeldung', 'bei', 'der', 'IV'], label=location, neighboring tokens=['Frau', 'Dr', '.', 'med', '.', 'Zihlschlacht-Sitterdorf', 'weitgehend', 'auf', 'die', 'Schilderung', 'der']
# sample 18
# label=location, neighboring tokens=['Clinica', 'Thomas', 'El', 'Masry', 'a', 'Senarclens', 'e', 'la', 'Clinica', 'Sarah', 'Berthelot'], label=location, neighboring tokens=['la', 'Clinica', 'Sarah', 'Berthelot', 'a', 'Oppligen', '.', 'Lo', 'scopo', 'iscritto', 'a']
# sample 19
# label=location, neighboring tokens=['habituelle', ',', 'se', 'trouvait', 'à', 'Froideville', ',', 'sur', 'la', 'commune', 'valaisanne'], label=location, neighboring tokens=['de', 'Rüschlikon', '(', 'ci-après', ':', 'Froideville', ')', ',', 'et', 'non', 'aux'], label=location, neighboring tokens=['celui-ci', 'était', 'bien', 'domicilié', 'à', 'Froideville', 'ou', 'à', 'tout', 'le', 'moins'], label=location, neighboring tokens=['est', 'constitué', 'un', 'domicile', 'à', 'Froideville', 'le', '1er', 'février', '2009', ','], label=location, neighboring tokens=['lui', 'avaient', 'été', 'notifiés', 'à', 'Froideville', ',', 'par', 'l', "'", 'intermédiaire'], label=location, neighboring tokens=["'", 'il', 'était', 'domicilié', 'à', 'Froideville', 'et', 'qu', "'", 'une', 'résidence'], label=location, neighboring tokens=["'", 'il', 'était', 'domicilié', 'à', 'Froideville', '.', 'Il', 'se', 'contente', 'à'], label=location, neighboring tokens=['13', 'millions', 'de', 'francs', 'à', 'Froideville', 'à', 'ses', 'enfants', 'mineurs', 'tout'], label=location, neighboring tokens=['sur', 'la', 'commune', 'valaisanne', 'de', 'Rüschlikon', '(', 'ci-après', ':', 'Froideville', ')'], label=location, neighboring tokens=['recourant', 'a', 'quitté', 'la', 'commune', 'Safiental', '(', 'NL', ')', 'le', '1'], label=location, neighboring tokens=['sa', 'famille', 'est', 'domiciliée', 'à', 'Safiental', '(', 'NL', ')', ',', 'ce'], label=location, neighboring tokens=['sa', 'famille', 'serait', 'domiciliée', 'à', 'Safiental', '(', 'NL', ')', ',', 'il']
# sample 20
# label=location, neighboring tokens=['der', 'streitgegenständlichen', '14', 'kg', 'Gold', 'Vionnaz', 'vereinbart', 'und', 'damit', 'eine', 'Bringschuld'], label=location, neighboring tokens=['Zweigniederlassung', 'der', 'Beschwerdeführerin', '2', 'in', 'Vionnaz', 'stattfinden', 'sollen', '.', 'Das', 'habe'], label=location, neighboring tokens=['Zweigniederlassung', 'der', 'Beschwerdeführerin', '2', 'in', 'Vionnaz', '.', 'Gemäss', 'Erstinstanz', 'machte', 'es'], label=location, neighboring tokens=['und', 'dem', 'Obergericht', 'des', 'Kantons', 'Vionnaz', ',', 'I', '.', 'Zivilkammer', ',']

# %%
print_entities(data,neighboring=True,label='organization')
# Out:
# sample 1
# label=organization, neighboring tokens=['société', 'Jobs', 'Grischun', 'Sàrl'], label=organization, neighboring tokens=['société', 'Baksi', 'Group', 'Sàrl'], label=organization, neighboring tokens=['société', 'Baksi', 'Group', 'Sàrl'], label=organization, neighboring tokens=['société', 'Baksi', 'Group', 'Sàrl'], label=organization, neighboring tokens=['société', 'Baksi', 'Group', 'Sàrl'], label=organization, neighboring tokens=['société', 'Baksi', 'Group', 'Sàrl']
# sample 2
# label=organization, neighboring tokens=['Firma', 'Business', 'Operation', 'Systems', 'AG']
# sample 3
# label=organization, neighboring tokens=['ditta', 'Sdplus', 'Holding', 'SA'], label=organization, neighboring tokens=['la', 'Sdplus', 'Holding', 'SA'], label=organization, neighboring tokens=['ditta', 'Sdplus', 'Holding', 'SA'], label=organization, neighboring tokens=['Ditta', 'Sdplus', 'Holding', 'SA']
# sample 4
# label=organization, neighboring tokens=['société', 'Buchdruckerei', 'Davos', 'SA'], label=organization, neighboring tokens=['de', 'Buchdruckerei', 'Davos', 'SA'], label=organization, neighboring tokens=['société', 'Buchdruckerei', 'Davos', 'SA'], label=organization, neighboring tokens=['société', 'Buchdruckerei', 'Davos', 'SA'], label=organization, neighboring tokens=['de', 'Buchdruckerei', 'Davos', 'SA'], label=organization, neighboring tokens=['de', 'Buchdruckerei', 'Davos', 'SA'], label=organization, neighboring tokens=['société', 'Buchdruckerei', 'Davos', 'SA'], label=organization, neighboring tokens=['société', 'Buchdruckerei', 'Davos', 'SA'], label=organization, neighboring tokens=['société', 'Buchdruckerei', 'Davos', 'SA'], label=organization, neighboring tokens=['société', 'Buchdruckerei', 'Davos', 'SA'], label=organization, neighboring tokens=['de', 'Buchdruckerei', 'Davos', 'SA'], label=organization, neighboring tokens=['société', 'Buchdruckerei', 'Davos', 'SA'], label=organization, neighboring tokens=['société', 'Buchdruckerei', 'Davos', 'SA'], label=organization, neighboring tokens=['société', 'Buchdruckerei', 'Davos', 'SA'], label=organization, neighboring tokens=['société', 'Buchdruckerei', 'Davos', 'SA'], label=organization, neighboring tokens=['société', 'Beacher', 'Concept', 'Switzerland', 'Sàrl'], label=organization, neighboring tokens=['à', 'Beacher', 'Concept', 'Switzerland', 'Sàrl']
# sample 5
# label=organization, neighboring tokens=['architecture', 'Hotel', 'Bernina', 'SA'], label=organization, neighboring tokens=['expertise', 'Hotel', 'Bernina', ',']
# sample 6
# label=organization, neighboring tokens=['procédure', 'Benninger', 'SA'], label=organization, neighboring tokens=['.', 'Benninger', 'SA'], label=organization, neighboring tokens=['contre', 'Benninger', 'SA'], label=organization, neighboring tokens=['.', 'Benninger', 'SA'], label=organization, neighboring tokens=['.', 'Benninger', 'SA'], label=organization, neighboring tokens=['par', 'Benninger', 'SA'], label=organization, neighboring tokens=['par', 'Benninger', 'SA'], label=organization, neighboring tokens=['.', 'Benninger', 'SA']
# sample 7
# label=organization, neighboring tokens=['Parties', 'Papyrus', 'Schweiz', 'SA'], label=organization, neighboring tokens=['et', 'Papyrus', 'Schweiz', 'SA'], label=organization, neighboring tokens=[':', 'Papyrus', 'Schweiz', ')'], label=organization, neighboring tokens=['de', 'Papyrus', 'Schweiz', '.'], label=organization, neighboring tokens=['à', 'Papyrus', 'Schweiz', 'l'], label=organization, neighboring tokens=[',', 'Papyrus', 'Schweiz', 'a'], label=organization, neighboring tokens=['à', 'Papyrus', 'Schweiz', '.'], label=organization, neighboring tokens=['.', 'Papyrus', 'Schweiz', 'a'], label=organization, neighboring tokens=[',', 'Papyrus', 'Schweiz', 'conclut']
# sample 8
# label=organization, neighboring tokens=['.', 'Prodo', 'AG'], label=organization, neighboring tokens=['Die', 'Prodo', 'AG'], label=organization, neighboring tokens=['die', 'Prodo', 'AG'], label=organization, neighboring tokens=['der', 'Prodo', 'AG'], label=organization, neighboring tokens=['der', 'Prodo', 'AG'], label=organization, neighboring tokens=['die', 'Prodo', 'AG'], label=organization, neighboring tokens=['gegen', 'Lötscher', '&', 'Co', 'AG'], label=organization, neighboring tokens=['Nachführungsgeometer', 'Lötscher', '&', 'Co', 'AG'], label=organization, neighboring tokens=['Die', 'Lötscher', '&', 'Co', 'AG']
# sample 9
# label=organization, neighboring tokens=['par', 'Hasler', 'Fenster', 'SA'], label=organization, neighboring tokens=['par', 'Mediapark', 'SA']
# sample 10
# label=organization, neighboring tokens=['der', 'Patrimonium', 'Asset', 'Management', 'AG']

# %%
explore_label(data,'person',most_common=20)
# Out:
# total number of entities for label person: 986117
# total number of unique entities for label person : 231048
# Ratio of unique/total entities : 0.2343007979783332
# [('Isabelle Henseler', 283),
#  ('Claudia Habenicht', 251),
#  ('Marc Planta', 243),
#  ('Enna Bühler', 242),
#  ('Yves Loosli', 224),
#  ('Adhanom Schweizer', 218),
#  ('Sara Imsand', 214),
#  ('Chiara Feuz', 203),
#  ('Rainer Mabilama', 194),
#  ('Nan Saraiva', 188),
#  ('Florian Ridoux', 175),
#  ('Michael Gremaud', 169),
#  ('Dean Jakupovic', 168),
#  ('Noel Alili', 165),
#  ('Gioia Skenderi', 162),
#  ('Leona Koudelka', 160),
#  ('Stéphanie Kellenberger', 158),
#  ('Deogratias Aeberhard', 157),
#  ('Emma Forestier', 154),
#  ('Elsbeth Wüscher', 152)]

# %%
explore_label(data,'location')
# Out:
# total number of entities for label location: 38122
# total number of unique entities for label location : 2130
# Ratio of unique/total entities : 0.05587324904254761
# [('Stansstad', 220),
#  ('Chavannes-De-Bogis', 159),
#  ('Hüttikon', 156),
#  ('Wittenbach', 142),
#  ('Gilly', 134),
#  ('Herbetswil', 124),
#  ('Movelier', 117),
#  ('Signy-Avenex', 100),
#  ('Mühleberg', 90),
#  ('Orvin', 86),
#  ('Neuheim', 84),
#  ('Gerzensee', 84),
#  ('Pfäfers', 83),
#  ('Gossau', 79),
#  ('Wynau', 77),
#  ('Düdingen', 77),
#  ('Riehen', 76),
#  ('Degersheim', 76),
#  ('Nunningen', 73),
#  ('Oberrieden', 72)]

# %%
explore_label(data,'organization')
# Out:
# total number of entities for label organization: 135304
# total number of unique entities for label organization : 12585
# Ratio of unique/total entities : 0.09301277124105717
# [('Die Werke Versorgung Wallisellen', 700),
#  ('Lemo', 637),
#  ('Adnovum Informatik', 221),
#  ('Ssm Architekten', 214),
#  ('Jobconsult', 192),
#  ('Netsafe', 155),
#  ('Kaulquappe', 145),
#  ('Promodal. Ch', 141),
#  ('Kaiser Engineering', 139),
#  ('Tri Dental Implants Int', 139),
#  ('Gebr. Estermann', 127),
#  ('Standout - Online Marketing Agentur', 123),
#  ('Swissparts', 122),
#  ('Catmar', 118),
#  ('Innflow', 113),
#  ('First Choice Consulting', 113),
#  ('Elvefin', 112),
#  ('Tca Thomann Distribution', 108),
#  ('Beltronic It', 108),
#  ('Edelway', 108)]
